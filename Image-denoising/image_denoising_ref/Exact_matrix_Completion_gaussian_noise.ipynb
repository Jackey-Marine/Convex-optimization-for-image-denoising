# %%
import cvxpy as cp
import numpy as np

# %%
def sp_noise(image):
    row,col = image.shape
    s_vs_p = 0.5
    amount = 0.05
    out = np.copy(image)
    # Salt mode
    num_salt = np.ceil(amount * image.size * s_vs_p)
    coords = [np.random.randint(0, i - 1, int(num_salt)) for i in image.shape]
    out[coords] = 1

    # Pepper mode
    num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
    coords = [np.random.randint(0, i - 1, int(num_pepper))
          for i in image.shape]
    out[coords] = 0
    return out

# %%
#Quadratic Filter
def quadratic_filter(im, lamb=1):
    '''Quadratic Filter.

    Args:
        im (np.ndarray): The noisy image to be filtered.
        lamb (float): The free parameter (lambda) that determines how much to correct.

    Returns:
        clean_im (np.ndarray): The filtered image.
    '''

    X = cp.Variable(im.shape)
    dXdx = cp.diff(X, k=1, axis=0)
    dXdy = cp.diff(X, k=1, axis=1)
    objective = cp.Minimize(cp.sum_squares(X - im) + lamb * cp.sum_squares(dXdx) + lamb * cp.sum_squares(dXdy))

    prob = cp.Problem(objective)
    try:
        prob.solve(verbose=True)
    except cp.SolverError as e:
        print('[ERROR] Quadratic Filter Failed.')
        print(e)
        exit()
    clean_im = X.value
    return clean_im

# %%
'''Total Variation (L1) Filter'''
def TV_filter_pd(im, lamb=1, niter=100):
    '''Total Variation (L1) Filter coded using the primal dual algorithm.

    Args:
        im (np.ndarray): The noisy image to be filtered.
        lamb (float): The free parameter (lambda) that determines how much to correct.
        niter (int): The number of iterations to run.

    Returns:
        clean_im (np.ndarray): The filtered image.
    '''
    tau = 0.02
    sigma = 1.0 / (8.0 * tau)
    lt = lamb * tau
    n = im.shape[0]

    clean_im = im
    shift = list(range(1, n)) + [n - 1]

    p = np.zeros((n, n, 2))
    p[:, :, 0] = clean_im[:, shift] - clean_im
    p[:, :, 1] = clean_im[shift, :] - clean_im

    for _ in range(niter):
        ux = clean_im[:, shift] - clean_im
        uy = clean_im[shift, :] - clean_im
        p = p + sigma * np.dstack([ux, uy])

        normep = np.maximum(1, np.sqrt(np.square(p[:, :, 0]) + np.square(p[:, :, 1])))
        p[:, :, 0] = p[:, :, 0] / normep
        p[:, :, 1] = p[:, :, 1] / normep

        div = np.vstack((p[0:n - 1, :, 1], np.zeros((1, n)))) - np.vstack((np.zeros((1, n)), p[0:n - 1, :, 1]))
        div = np.hstack((p[:, 0:n - 1, 0], np.zeros((n, 1)))) - np.hstack((np.zeros((n, 1)), p[:, 0:n - 1, 0])) + div

        clean_im = (clean_im + tau * div + lt * im) / (1 + tau)
    return clean_im

# %%
'''A collection of utility functions. '''

import os
from math import log10, sqrt

import numpy as np
from PIL import Image


def read_image(filename):
    '''Reads one of the images, resizes them, and normalizes them to have pixels between 0 and 1.

    Args:
        filename (str): The name of the image to be read (e.g. clock).

    Returns:
        im (np.ndarray): The normalized, resized image.
    '''
    im = Image.open(f'./images/{filename}.jpg')
    im = im.resize((256, 256))
    im = np.array(im)
    im = normalize_image(im)
    return im


def add_gaussian_noise(im, mean=0, var=0.01):
    '''Adds Gaussian noise to an image with the given variance.

    Args:
        mean (float): The mean of the Gaussian noise that is added.
        var (float): The variance of the Gaussian noise that is added.

    Returns:
        noisy_im (np.ndarray): The noisy image.
    '''
    sigma = var**0.5
    gaussian_noise = np.random.normal(mean, sigma, im.shape)
    noisy_im = im + gaussian_noise
    noisy_im = normalize_image(noisy_im)
    return noisy_im


def add_poisson_noise(im, photons=100):
    '''Adds Poisson noise to an image with the given variance.

    Args:
        photons (float): The number of photons available per pixel.

    Returns:
        noisy_im (np.ndarray): The noisy image.
    '''
    noisy_im = np.random.poisson(im * photons) / photons
    noisy_im = normalize_image(noisy_im)
    return noisy_im


def normalize_image(im):
    '''Normalizes an image to have pixels only from 0-1

    Args:
        im (np.ndarray): The image to be normalized.

    Returns:
        normalized_im (np.ndarray): The normalized image.
    '''
    max_pixel = np.max(im)
    min_pixel = np.min(im)
    normalized_im = (im - min_pixel) / max_pixel
    return normalized_im


def PSNR(original_im, cleaned_im):
    '''Calculates the Peak Signal-to-Noise Ratio (PSNR) between two images.

    Args:
        original_im (np.ndarray): The original image (without any noise).
        cleaned_im (np.ndarray): The filtered image (trying to clear the noise).

    Returns:
        psnr (float): The normalized, resized image.
    '''
    mse = np.mean((original_im - cleaned_im)**2)
    if mse == 0:
        return 100
    max_pixel = 1.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr


def create_results_directory(noise_type, images, hyperparameters):
    '''Creates the necessary results directory structure.

    Args:
        noise_type (str): The type of noise, either 'gaussian' or 'poisson'.
        images (list): The list of image names, e.g. 'clock'.
        hyperparameters (list): The list of hyperparameters for that noise being tested.
    '''
    for image in images:
        for var in hyperparameters:
            str_var = str(var).replace('.', '_')
            os.makedirs(f'./results/{noise_type}/{image}/var_{str_var}/', exist_ok=True)

# %%
'''Main file for running experiments.'''

import time
import pickle

import numpy as np
import matplotlib.pyplot as plt

noise_type = 'gaussian'
plot = False
savefigs = True

np.random.seed(0)

PSNR_results = {'quad': {}, 'TV': {}, 'nlm': {}, 'wnnm': {}}
time_results = {'quad': {}, 'TV': {}, 'nlm': {}, 'wnnm': {}}

images = ['Insulators_1']

if noise_type == 'gaussian':
    hyperparameters = [0.05]#, 0.025, 0.05]
elif noise_type == 'poisson':
    hyperparameters = [50, 20, 10]
elif noise_type == 'saltpepper':
    hyperparameters = [0.05]

create_results_directory(noise_type, images, hyperparameters)

for im_name in images:
    for key in PSNR_results.keys():
        PSNR_results[key][im_name] = []
        time_results[key][im_name] = []

    for param in hyperparameters:
        str_var = str(param).replace('.', '_')

        im = read_image(im_name)
        if noise_type == 'gaussian':
            noisy_im = add_gaussian_noise(im, mean=0, var=param)
            variance = param
        elif noise_type == 'poisson':
            noisy_im = add_poisson_noise(im, photons=param)
            variance = 0.5/param
        elif noise_type == 'saltpepper':
            noisy_im = sp_noise(im)
            print(type)

        start_time = time.time()

        quad_im = quadratic_filter(noisy_im, 5)
        quad_time = time.time()
        quad_im = normalize_image(quad_im)

        # TV_im = TV_filter(noisy_im, 0.3)
        TV_im = TV_filter_pd(noisy_im, 6)
        TV_time = time.time()
        TV_im = normalize_image(TV_im)

        # nlm_im = non_local_means_filter(noisy_im, 7, 10, 0.1)
        # nlm_time = time.time()
        # nlm_im = normalize_image(nlm_im)

        # x = noisy_im
        # y = noisy_im
        # delta = 0.3
        # for _ in range(1):
        #     y = x + delta*(noisy_im - y)
        #     x = non_local_wnnm_filter(y, 7, 10, variance)
        #     x = normalize_image(x)

        # wnnm_im = x

        # wnnm_time = time.time()

        PSNR_results['quad'][im_name].append(PSNR(original_im=im, cleaned_im=quad_im))
        PSNR_results['TV'][im_name].append(PSNR(original_im=im, cleaned_im=TV_im))
#             PSNR_results['nlm'][im_name].append(PSNR(original_im=im, cleaned_im=nlm_im))
#             PSNR_results['wnnm'][im_name].append(PSNR(original_im=im, cleaned_im=wnnm_im))

        time_results['quad'][im_name].append(quad_time - start_time)
        time_results['TV'][im_name].append(TV_time - quad_time)
#             time_results['nlm'][im_name].append(nlm_time - TV_time)
#             time_results['wnnm'][im_name].append(wnnm_time - nlm_time)

        if plot is True or savefigs is True:
            _, ax_original = plt.subplots()
            ax_original.imshow(im, cmap='gray')
            ax_original.set_title('Original Image')
#             print(im)

            fig_noisy, ax_noisy = plt.subplots()
            ax_noisy.imshow(noisy_im, cmap='gray')
            ax_noisy.set_title(f'Noisy Image, PSNR={round(PSNR(original_im=im, cleaned_im=noisy_im), 2)}')

            fig_quad, ax_quad = plt.subplots()
            ax_quad.imshow(quad_im, cmap='gray')
            ax_quad.set_title(f'Quadratic Image, PSNR={round(PSNR(original_im=im, cleaned_im=quad_im), 2)}')

            fig_tv, ax_tv = plt.subplots()
            ax_tv.imshow(TV_im, cmap='gray')
            ax_tv.set_title(f'TV Image, PSNR={round(PSNR(original_im=im, cleaned_im=TV_im), 2)}')

#                 fig_nlm, ax_nlm = plt.subplots()
#                 ax_nlm.imshow(nlm_im, cmap='gray')
#                 ax_nlm.set_title(f'Non-local means Image, PSNR={round(PSNR(original_im=im, cleaned_im=nlm_im), 2)}')

#                 fig_wnnm, ax_wnnm = plt.subplots()
#                 ax_wnnm.imshow(wnnm_im, cmap='gray')
#                 ax_wnnm.set_title(f'Weighted Nuclear Norm Minimization Image, PSNR={round(PSNR(original_im=im, cleaned_im=wnnm_im), 2)}')

            if savefigs is True:
                fig_noisy.savefig(f'./results/{noise_type}/{im_name}/var_{str_var}/noisy.png')
                fig_quad.savefig(f'./results/{noise_type}/{im_name}/var_{str_var}/quad.png')
                fig_tv.savefig(f'./results/{noise_type}/{im_name}/var_{str_var}/tv.png')
#                     fig_nlm.savefig(f'./results/{noise_type}/{im_name}/var_{str_var}/nlm.png')
#                     fig_wnnm.savefig(f'./results/{noise_type}/{im_name}/var_{str_var}/wnnm.png')

            if plot is True:
                plt.show()

print(PSNR_results)
print(time_results)
with open(f'./results/{noise_type}/PSNR_results.pkl', 'wb') as f:
    pickle.dump(PSNR_results, f)
with open(f'./results/{noise_type}/time_results.pkl', 'wb') as f:
    pickle.dump(time_results, f)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Dec 25 04:36:50 PM: Your problem has 65536 variables, 0 constraints, and 0 parameters.
# (CVXPY) Dec 25 04:36:50 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Dec 25 04:36:50 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Dec 25 04:36:50 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Dec 25 04:36:50 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Dec 25 04:36:50 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Dec 25 04:36:50 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Dec 25 04:36:50 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Dec 25 04:36:50 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Dec 25 04:36:50 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Dec 25 04:36:50 PM: Applying reduction OSQP
# (CVXPY) Dec 25 04:36:50 PM: Finished problem compilation (took 4.683e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Dec 25 04:36:50 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 261632, constraints m = 196096
#           nnz(P) + nnz(A) = 718848
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.48e+00   1.48e+02   1.00e-01   3.97e-01s
#   50   1.6284e+03   2.09e-09   1.99e-09   1.00e-01   1.11e+00s
# plsh   1.6284e+03   2.22e-16   7.22e-16   --------   1.46e+00s
#
# status:               solved
# solution polish:      successful
# number of iterations: 50
# optimal objective:    1628.4339
# run time:             1.46e+00s
# optimal rho estimate: 8.22e-02
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Dec 25 04:36:52 PM: Problem status: optimal
# (CVXPY) Dec 25 04:36:52 PM: Optimal value: 1.628e+03
# (CVXPY) Dec 25 04:36:52 PM: Compilation took 4.683e-01 seconds
# (CVXPY) Dec 25 04:36:52 PM: Solver (including time spent in interface) took 1.520e+00 seconds
# {'quad': {'Insulators_1': [12.82250249369029]}, 'TV': {'Insulators_1': [13.177782724741169]}, 'nlm': {'Insulators_1': []}, 'wnnm': {'Insulators_1': []}}
# {'quad': {'Insulators_1': [2.1210219860076904]}, 'TV': {'Insulators_1': [0.204817533493042]}, 'nlm': {'Insulators_1': []}, 'wnnm': {'Insulators_1': []}}

# %%
# Exact Matrix Completion
# complete_matrix() should work with any matrix, symmetric or not.
# complete_psd_symmetric() will work with psd symmetric matrices only, but is faster.

# This is the meat of my project.
# complete_matrix() should work with any matrix, symmetric or not.
# complete_psd_symmetric() will work with psd symmetric matrices only, but is faster.

import numpy as np
import cvxpy as cp
import random

def complete_psd_symmetric(M, omega):
    """
    If M is already symmetric PSD, can safely use this
    to recover the matrix.
    """
    X = cp.Variable(M.shape, PSD=True)

    constraints = [X == X.T] # symmetry constraint
    for i, j in omega:
        constraints += [X[i, j] == M[i, j]] # equality constraint for sampled entries

    # Minimize surrogate of nuclear norm: trace
    problem = cp.Problem(cp.Minimize(cp.trace(X)), constraints)
    problem.solve()

    return X.value

def complete_matrix(M, omega):
    """
    If M is not guaranteed to by symmetric PSD, use this function instead.
    """

    """
    create a decision variable which has shape 2n X 2n
    essentially,
    | W1 X  |
    | X* W2 |
    we want to minimize Tr(W1) + Tr(W2), but only really care
    about X as this will be our original reconstructed matrix.
    The reason for introducing W1, W2, and X* is because 
    we want to minimize the trace of a symmetric PSD matrix.
    
    This implementation loosely inspired by Joonyoung Yi: https://github.com/JoonyoungYi/MCCO-numpy
    """
    X = cp.Variable([np.sum(M.shape), np.sum(M.shape)], PSD=True) # create the 2n X 2n matrix

    constraints = [X == X.T] # symmetry constraint
    for i, j in omega:
        constraints += [X[i, j + M.shape[0]] == M[i, j]] # equality constraint for sampled entries

    # Minimize surrogate of nuclear norm: trace(X)
    problem = cp.Problem(cp.Minimize(cp.trace(X)), constraints)
    problem.solve()

    # return top right corner of matrix
    return X.value[:M.shape[0], M.shape[0]:]

def mask_out_matrix(X, entries):
    mask = np.zeros(X.shape)
    omega = random.sample([(i, j) for i in range(X.shape[0]) for j in range(X.shape[1])], entries)
    for (i, j) in omega:
        mask[i, j] = 1
    return X.copy() * mask, omega

# n        = 30
# rank     = 8
# m        = int(0.4 * n**(1.25) * rank * np.log(n))
# M        = np.dot(np.random.randn(n, rank), np.random.randn(n, rank).T)
# X, omega = mask_out_matrix(M, m) # strictly speaking, not necessary

# print("Nuclear Norm of original matrix M: {:6.4f}".format(np.linalg.norm(M, "nuc")))
# print('Average entry-wise difference before recovery:', np.mean(np.abs(M - X)))

# recovered = complete_matrix(X, omega)

# print('Average entry-wise difference after recovery:', np.mean(np.abs(M - recovered)))
# print("Nuclear Norm of recoverd matrix: {:6.4f}".format(np.linalg.norm(recovered, "nuc")))

# %%
im
# Out:
# array([[0.39215686, 0.48235294, 0.70980392, ..., 0.44705882, 0.45098039,
#         0.49803922],
#        [0.30588235, 0.29019608, 0.42352941, ..., 0.47843137, 0.54901961,
#         0.58823529],
#        [0.29803922, 0.34901961, 0.32156863, ..., 0.44313725, 0.43921569,
#         0.43921569],
#        ...,
#        [0.25098039, 0.25882353, 0.34901961, ..., 0.36470588, 0.34117647,
#         0.33333333],
#        [0.24313725, 0.24313725, 0.23921569, ..., 0.35686275, 0.36470588,
#         0.36470588],
#        [0.31764706, 0.25490196, 0.23921569, ..., 0.32156863, 0.32941176,
#         0.35294118]])

# %%
#noisy_im
#im
import cv2
difference = cv2.absdiff(im, noisy_im)
threshold = 0.15

# Create a binary mask indicating noisy pixels
noisy_pixel_mask = difference > threshold

_, ax_image = plt.subplots()
ax_image.imshow(im, cmap='gray')
ax_image.set_title('Original Image')

_, ax_noisy = plt.subplots()
ax_noisy.imshow(noisy_im, cmap='gray')
ax_noisy.set_title('Noisy Image')

_, ax_noisy_mask = plt.subplots()
ax_noisy_mask.imshow(noisy_pixel_mask, cmap='gray')
ax_noisy_mask.set_title('Mask')

plt.show()

# %%
inverted_mask = ~noisy_pixel_mask
noisy_pixel_coordinates = np.where(inverted_mask)
true_coordinates = np.where(inverted_mask)
coords = []
# Print the coordinates
for row, col in zip(*true_coordinates):
    print(f"Row: {row}, Column: {col}")
    coords.append((row,col))
print(coords)
updated_coords = coords
# Out:
# Row: 0, Column: 19
# Row: 0, Column: 20
# Row: 0, Column: 25
# Row: 0, Column: 33
# Row: 0, Column: 48
# Row: 0, Column: 62
# Row: 0, Column: 63
# Row: 0, Column: 73
# Row: 0, Column: 101
# Row: 0, Column: 102
# Row: 0, Column: 104
# Row: 0, Column: 112
# Row: 0, Column: 140
# Row: 0, Column: 167
# Row: 0, Column: 183
# Row: 0, Column: 185
# Row: 0, Column: 193
# Row: 0, Column: 205
# Row: 0, Column: 224
# Row: 0, Column: 230
# Row: 0, Column: 237
# Row: 0, Column: 245
# Row: 0, Column: 249
# Row: 1, Column: 2
# Row: 1, Column: 4
# Row: 1, Column: 8
# Row: 1, Column: 15
# Row: 1, Column: 18
# Row: 1, Column: 22
# Row: 1, Column: 64
# Row: 1, Column: 78
# Row: 1, Column: 87
# Row: 1, Column: 94
# Row: 1, Column: 95
# Row: 1, Column: 97
# Row: 1, Column: 98
# Row: 1, Column: 99
# Row: 1, Column: 100
# Row: 1, Column: 113
# Row: 1, Column: 115
# Row: 1, Column: 124
# Row: 1, Column: 126
# Row: 1, Column: 129
# Row: 1, Column: 131
# Row: 1, Column: 137
# Row: 1, Column: 148
# Row: 1, Column: 154
# Row: 1, Column: 166
# Row: 1, Column: 171
# Row: 1, Column: 175
# Row: 1, Column: 194
# Row: 1, Column: 201
# Row: 1, Column: 212
# Row: 1, Column: 214
# Row: 1, Column: 229
# Row: 1, Column: 250
# Row: 1, Column: 251
# Row: 1, Column: 252
# Row: 2, Column: 1
# Row: 2, Column: 10
# Row: 2, Column: 16
# Row: 2, Column: 18
# Row: 2, Column: 22
# Row: 2, Column: 35
# Row: 2, Column: 44
# Row: 2, Column: 59
# Row: 2, Column: 68
# Row: 2, Column: 77
# Row: 2, Column: 88
# Row: 2, Column: 90
# Row: 2, Column: 92
# Row: 2, Column: 93
# Row: 2, Column: 95
# Row: 2, Column: 98
# Row: 2, Column: 99
# Row: 2, Column: 107
# Row: 2, Column: 113
# Row: 2, Column: 139
# Row: 2, Column: 156
# Row: 2, Column: 159
# Row: 2, Column: 160
# Row: 2, Column: 173
# Row: 2, Column: 175
# Row: 2, Column: 180
# Row: 2, Column: 181
# Row: 2, Column: 188
# Row: 2, Column: 212
# Row: 2, Column: 223
# Row: 2, Column: 229
# Row: 2, Column: 236
# Row: 2, Column: 239
# Row: 2, Column: 247
# Row: 3, Column: 7
# Row: 3, Column: 15
# Row: 3, Column: 20
# Row: 3, Column: 40
# Row: 3, Column: 82
# Row: 3, Column: 88
# Row: 3, Column: 90
# Row: 3, Column: 97
# Row: 3, Column: 100
# Row: 3, Column: 103
# Row: 3, Column: 105
# Row: 3, Column: 107
# Row: 3, Column: 109
# Row: 3, Column: 111
# Row: 3, Column: 129
# Row: 3, Column: 132
# Row: 3, Column: 143
# Row: 3, Column: 145
# Row: 3, Column: 239
# Row: 3, Column: 249
# Row: 4, Column: 9
# Row: 4, Column: 15
# Row: 4, Column: 47
# Row: 4, Column: 89
# Row: 4, Column: 98
# Row: 4, Column: 99
# Row: 4, Column: 105
# Row: 4, Column: 106
# Row: 4, Column: 116
# Row: 4, Column: 117
# Row: 4, Column: 135
# Row: 4, Column: 160
# Row: 4, Column: 174
# Row: 4, Column: 177
# Row: 4, Column: 210
# Row: 4, Column: 211
# Row: 4, Column: 225
# Row: 4, Column: 232
# Row: 4, Column: 237
# Row: 4, Column: 242
# Row: 4, Column: 244
# Row: 4, Column: 246
# Row: 4, Column: 253
# Row: 4, Column: 254
# Row: 5, Column: 19
# Row: 5, Column: 20
# Row: 5, Column: 25
# Row: 5, Column: 39
# Row: 5, Column: 96
# Row: 5, Column: 117
# Row: 5, Column: 122
# Row: 5, Column: 135
# Row: 5, Column: 137
# Row: 5, Column: 138
# Row: 5, Column: 151
# Row: 5, Column: 152
# Row: 5, Column: 166
# Row: 5, Column: 214
# Row: 5, Column: 232
# Row: 5, Column: 233
# Row: 5, Column: 248
# Row: 5, Column: 250
# Row: 5, Column: 252
# Row: 6, Column: 7
# Row: 6, Column: 36
# Row: 6, Column: 37
# Row: 6, Column: 47
# Row: 6, Column: 73
# Row: 6, Column: 76
# Row: 6, Column: 92
# Row: 6, Column: 103
# Row: 6, Column: 110
# Row: 6, Column: 116
# Row: 6, Column: 126
# Row: 6, Column: 127
# Row: 6, Column: 153
# Row: 6, Column: 154
# Row: 6, Column: 164
# Row: 6, Column: 172
# Row: 6, Column: 185
# Row: 6, Column: 207
# Row: 6, Column: 209
# Row: 6, Column: 210
# Row: 6, Column: 211
# Row: 6, Column: 217
# Row: 6, Column: 226
# Row: 6, Column: 246
# Row: 6, Column: 250
# Row: 6, Column: 253
# Row: 7, Column: 14
# Row: 7, Column: 18
# Row: 7, Column: 23
# Row: 7, Column: 33
# Row: 7, Column: 39
# Row: 7, Column: 47
# Row: 7, Column: 52
# Row: 7, Column: 81
# Row: 7, Column: 89
# Row: 7, Column: 92
# Row: 7, Column: 94
# Row: 7, Column: 98
# Row: 7, Column: 105
# Row: 7, Column: 119
# Row: 7, Column: 125
# Row: 7, Column: 129
# Row: 7, Column: 160
# Row: 7, Column: 173
# Row: 7, Column: 193
# Row: 7, Column: 196
# Row: 7, Column: 208
# Row: 7, Column: 209
# Row: 7, Column: 226
# Row: 7, Column: 228
# Row: 8, Column: 0
# Row: 8, Column: 2
# Row: 8, Column: 15
# Row: 8, Column: 16
# Row: 8, Column: 18
# Row: 8, Column: 37
# Row: 8, Column: 41
# Row: 8, Column: 47
# Row: 8, Column: 66
# Row: 8, Column: 75
# Row: 8, Column: 87
# Row: 8, Column: 96
# Row: 8, Column: 97
# Row: 8, Column: 101
# Row: 8, Column: 102
# Row: 8, Column: 104
# Row: 8, Column: 107
# Row: 8, Column: 111
# Row: 8, Column: 132
# Row: 8, Column: 134
# Row: 8, Column: 167
# Row: 8, Column: 184
# Row: 8, Column: 192
# Row: 8, Column: 196
# Row: 8, Column: 206
# Row: 8, Column: 214
# Row: 8, Column: 216
# Row: 9, Column: 13
# Row: 9, Column: 18
# Row: 9, Column: 33
# Row: 9, Column: 38
# Row: 9, Column: 50
# Row: 9, Column: 55
# Row: 9, Column: 56
# Row: 9, Column: 61
# Row: 9, Column: 68
# Row: 9, Column: 94
# Row: 9, Column: 128
# Row: 9, Column: 131
# Row: 9, Column: 161
# Row: 9, Column: 168
# Row: 9, Column: 196
# Row: 9, Column: 203
# Row: 9, Column: 204
# Row: 9, Column: 215
# Row: 9, Column: 246
# Row: 9, Column: 247
# Row: 10, Column: 13
# Row: 10, Column: 14
# Row: 10, Column: 18
# Row: 10, Column: 20
# Row: 10, Column: 21
# Row: 10, Column: 31
# Row: 10, Column: 43
# Row: 10, Column: 58
# Row: 10, Column: 84
# Row: 10, Column: 88
# Row: 10, Column: 89
# Row: 10, Column: 94
# Row: 10, Column: 107
# Row: 10, Column: 122
# Row: 10, Column: 132
# Row: 10, Column: 140
# Row: 10, Column: 141
# Row: 10, Column: 142
# Row: 10, Column: 167
# Row: 10, Column: 189
# Row: 10, Column: 216
# Row: 10, Column: 226
# Row: 10, Column: 241
# Row: 10, Column: 246
# Row: 11, Column: 14
# Row: 11, Column: 16
# Row: 11, Column: 50
# Row: 11, Column: 51
# Row: 11, Column: 61
# Row: 11, Column: 65
# Row: 11, Column: 83
# Row: 11, Column: 88
# Row: 11, Column: 89
# Row: 11, Column: 92
# Row: 11, Column: 118
# Row: 11, Column: 122
# Row: 11, Column: 125
# Row: 11, Column: 130
# Row: 11, Column: 132
# Row: 11, Column: 134
# Row: 11, Column: 140
# Row: 11, Column: 166
# Row: 11, Column: 192
# Row: 11, Column: 197
# Row: 11, Column: 198
# Row: 11, Column: 204
# Row: 11, Column: 209
# Row: 11, Column: 248
# Row: 12, Column: 0
# Row: 12, Column: 13
# Row: 12, Column: 31
# Row: 12, Column: 52
# Row: 12, Column: 90
# Row: 12, Column: 96
# Row: 12, Column: 102
# Row: 12, Column: 128
# Row: 12, Column: 130
# Row: 12, Column: 131
# Row: 12, Column: 139
# Row: 12, Column: 141
# Row: 12, Column: 145
# Row: 12, Column: 151
# Row: 12, Column: 176
# Row: 12, Column: 188
# Row: 12, Column: 191
# Row: 12, Column: 193
# Row: 12, Column: 195
# Row: 12, Column: 216
# Row: 12, Column: 228
# Row: 12, Column: 230
# Row: 12, Column: 240
# Row: 12, Column: 243
# Row: 12, Column: 244
# Row: 12, Column: 245
# Row: 12, Column: 255
# Row: 13, Column: 0
# Row: 13, Column: 42
# Row: 13, Column: 72
# Row: 13, Column: 79
# Row: 13, Column: 92
# Row: 13, Column: 104
# Row: 13, Column: 109
# Row: 13, Column: 112
# Row: 13, Column: 126
# Row: 13, Column: 134
# Row: 13, Column: 142
# Row: 13, Column: 157
# Row: 13, Column: 191
# Row: 13, Column: 196
# Row: 13, Column: 217
# Row: 13, Column: 239
# Row: 13, Column: 254
# Row: 14, Column: 3
# Row: 14, Column: 13
# Row: 14, Column: 79
# Row: 14, Column: 84
# Row: 14, Column: 113
# Row: 14, Column: 124
# Row: 14, Column: 151
# Row: 14, Column: 159
# Row: 14, Column: 168
# Row: 14, Column: 201
# Row: 14, Column: 204
# Row: 14, Column: 218
# Row: 14, Column: 234
# Row: 14, Column: 255
# Row: 15, Column: 10
# Row: 15, Column: 13
# Row: 15, Column: 32
# Row: 15, Column: 33
# Row: 15, Column: 34
# Row: 15, Column: 72
# Row: 15, Column: 75
# Row: 15, Column: 82
# Row: 15, Column: 91
# Row: 15, Column: 114
# Row: 15, Column: 124
# Row: 15, Column: 127
# Row: 15, Column: 142
# Row: 15, Column: 150
# Row: 15, Column: 169
# Row: 15, Column: 173
# Row: 15, Column: 180
# Row: 15, Column: 194
# Row: 15, Column: 204
# Row: 15, Column: 210
# Row: 15, Column: 224
# Row: 15, Column: 234
# Row: 15, Column: 242
# Row: 15, Column: 243
# Row: 15, Column: 249
# Row: 16, Column: 3
# Row: 16, Column: 4
# Row: 16, Column: 6
# Row: 16, Column: 10
# Row: 16, Column: 21
# Row: 16, Column: 24
# Row: 16, Column: 25
# Row: 16, Column: 42
# Row: 16, Column: 52
# Row: 16, Column: 56
# Row: 16, Column: 83
# Row: 16, Column: 107
# Row: 16, Column: 113
# Row: 16, Column: 119
# Row: 16, Column: 120
# Row: 16, Column: 133
# Row: 16, Column: 142
# Row: 16, Column: 152
# Row: 16, Column: 168
# Row: 16, Column: 189
# Row: 16, Column: 203
# Row: 16, Column: 241
# Row: 16, Column: 247
# Row: 17, Column: 4
# Row: 17, Column: 25
# Row: 17, Column: 32
# Row: 17, Column: 33
# Row: 17, Column: 35
# Row: 17, Column: 38
# Row: 17, Column: 45
# Row: 17, Column: 63
# Row: 17, Column: 90
# Row: 17, Column: 95
# Row: 17, Column: 111
# Row: 17, Column: 117
# Row: 17, Column: 118
# Row: 17, Column: 122
# Row: 17, Column: 133
# Row: 17, Column: 135
# Row: 17, Column: 143
# Row: 17, Column: 155
# Row: 17, Column: 163
# Row: 17, Column: 228
# Row: 17, Column: 230
# Row: 17, Column: 234
# Row: 17, Column: 237
# Row: 17, Column: 244
# Row: 17, Column: 245
# Row: 18, Column: 36
# Row: 18, Column: 39
# Row: 18, Column: 66
# Row: 18, Column: 85
# Row: 18, Column: 92
# Row: 18, Column: 102
# Row: 18, Column: 105
# Row: 18, Column: 119
# Row: 18, Column: 126
# Row: 18, Column: 129
# Row: 18, Column: 152
# Row: 18, Column: 155
# Row: 18, Column: 156
# Row: 18, Column: 160
# Row: 18, Column: 176
# Row: 18, Column: 183
# Row: 18, Column: 185
# Row: 18, Column: 222
# Row: 18, Column: 241
# Row: 19, Column: 8
# Row: 19, Column: 20
# Row: 19, Column: 46
# Row: 19, Column: 92
# Row: 19, Column: 112
# Row: 19, Column: 121
# Row: 19, Column: 130
# Row: 19, Column: 138
# Row: 19, Column: 140
# Row: 19, Column: 149
# Row: 19, Column: 150
# Row: 19, Column: 157
# Row: 19, Column: 158
# Row: 19, Column: 159
# Row: 19, Column: 166
# Row: 19, Column: 170
# Row: 19, Column: 187
# Row: 19, Column: 191
# Row: 19, Column: 193
# Row: 19, Column: 197
# Row: 19, Column: 201
# Row: 19, Column: 204
# Row: 19, Column: 232
# Row: 19, Column: 240
# Row: 19, Column: 247
# Row: 19, Column: 251
# Row: 20, Column: 3
# Row: 20, Column: 5
# Row: 20, Column: 20
# Row: 20, Column: 35
# Row: 20, Column: 36
# Row: 20, Column: 37
# Row: 20, Column: 45
# Row: 20, Column: 63
# Row: 20, Column: 71
# Row: 20, Column: 83
# Row: 20, Column: 84
# Row: 20, Column: 111
# Row: 20, Column: 142
# Row: 20, Column: 151
# Row: 20, Column: 166
# Row: 20, Column: 173
# Row: 20, Column: 177
# Row: 20, Column: 187
# Row: 20, Column: 205
# Row: 20, Column: 208
# Row: 20, Column: 216
# Row: 20, Column: 224
# Row: 20, Column: 238
# Row: 20, Column: 241
# Row: 21, Column: 1
# Row: 21, Column: 5
# Row: 21, Column: 15
# Row: 21, Column: 39
# Row: 21, Column: 70
# Row: 21, Column: 81
# Row: 21, Column: 83
# Row: 21, Column: 84
# Row: 21, Column: 90
# Row: 21, Column: 96
# Row: 21, Column: 97
# Row: 21, Column: 109
# Row: 21, Column: 121
# Row: 21, Column: 131
# Row: 21, Column: 144
# Row: 21, Column: 154
# Row: 21, Column: 169
# Row: 21, Column: 177
# Row: 21, Column: 187
# Row: 21, Column: 206
# Row: 21, Column: 212
# Row: 21, Column: 218
# Row: 21, Column: 248
# Row: 22, Column: 39
# Row: 22, Column: 40
# Row: 22, Column: 44
# Row: 22, Column: 53
# Row: 22, Column: 79
# Row: 22, Column: 102
# Row: 22, Column: 108
# Row: 22, Column: 112
# Row: 22, Column: 124
# Row: 22, Column: 127
# Row: 22, Column: 133
# Row: 22, Column: 144
# Row: 22, Column: 150
# Row: 22, Column: 172
# Row: 22, Column: 180
# Row: 22, Column: 197
# Row: 22, Column: 210
# Row: 22, Column: 227
# Row: 22, Column: 241
# Row: 22, Column: 248
# Row: 22, Column: 249
# Row: 23, Column: 18
# Row: 23, Column: 29
# Row: 23, Column: 33
# Row: 23, Column: 38
# Row: 23, Column: 83
# Row: 23, Column: 94
# Row: 23, Column: 95
# Row: 23, Column: 107
# Row: 23, Column: 118
# Row: 23, Column: 119
# Row: 23, Column: 127
# Row: 23, Column: 172
# Row: 23, Column: 180
# Row: 23, Column: 182
# Row: 23, Column: 219
# Row: 23, Column: 226
# Row: 23, Column: 235
# Row: 23, Column: 241
# Row: 24, Column: 17
# Row: 24, Column: 20
# Row: 24, Column: 50
# Row: 24, Column: 66
# Row: 24, Column: 78
# Row: 24, Column: 93
# Row: 24, Column: 103
# Row: 24, Column: 112
# Row: 24, Column: 120
# Row: 24, Column: 133
# Row: 24, Column: 157
# Row: 24, Column: 163
# Row: 24, Column: 174
# Row: 24, Column: 181
# Row: 24, Column: 183
# Row: 24, Column: 186
# Row: 24, Column: 195
# Row: 24, Column: 199
# Row: 24, Column: 211
# Row: 24, Column: 218
# Row: 24, Column: 236
# Row: 24, Column: 238
# Row: 24, Column: 252
# Row: 25, Column: 1
# Row: 25, Column: 12
# Row: 25, Column: 20
# Row: 25, Column: 44
# Row: 25, Column: 56
# Row: 25, Column: 67
# Row: 25, Column: 92
# Row: 25, Column: 110
# Row: 25, Column: 114
# Row: 25, Column: 115
# Row: 25, Column: 130
# Row: 25, Column: 132
# Row: 25, Column: 143
# Row: 25, Column: 147
# Row: 25, Column: 150
# Row: 25, Column: 154
# Row: 25, Column: 158
# Row: 25, Column: 164
# Row: 25, Column: 181
# Row: 25, Column: 183
# Row: 25, Column: 199
# Row: 25, Column: 205
# Row: 25, Column: 225
# Row: 25, Column: 239
# Row: 26, Column: 2
# Row: 26, Column: 4
# Row: 26, Column: 24
# Row: 26, Column: 35
# Row: 26, Column: 47
# Row: 26, Column: 71
# Row: 26, Column: 75
# Row: 26, Column: 76
# Row: 26, Column: 83
# Row: 26, Column: 92
# Row: 26, Column: 103
# Row: 26, Column: 104
# Row: 26, Column: 118
# Row: 26, Column: 126
# Row: 26, Column: 128
# Row: 26, Column: 133
# Row: 26, Column: 155
# Row: 26, Column: 159
# Row: 26, Column: 175
# Row: 26, Column: 247
# Row: 26, Column: 248
# Row: 27, Column: 2
# Row: 27, Column: 20
# Row: 27, Column: 26
# Row: 27, Column: 49
# Row: 27, Column: 90
# Row: 27, Column: 96
# Row: 27, Column: 114
# Row: 27, Column: 116
# Row: 27, Column: 125
# Row: 27, Column: 126
# Row: 27, Column: 127
# Row: 27, Column: 139
# Row: 27, Column: 153
# Row: 27, Column: 161
# Row: 27, Column: 169
# Row: 27, Column: 189
# Row: 27, Column: 216
# Row: 27, Column: 235
# Row: 27, Column: 242
# Row: 27, Column: 249
# Row: 27, Column: 251
# Row: 27, Column: 255
# Row: 28, Column: 12
# Row: 28, Column: 47
# Row: 28, Column: 50
# Row: 28, Column: 51
# Row: 28, Column: 52
# Row: 28, Column: 63
# Row: 28, Column: 97
# Row: 28, Column: 111
# Row: 28, Column: 118
# Row: 28, Column: 120
# Row: 28, Column: 122
# Row: 28, Column: 125
# Row: 28, Column: 129
# Row: 28, Column: 136
# Row: 28, Column: 145
# Row: 28, Column: 156
# Row: 28, Column: 157
# Row: 28, Column: 162
# Row: 28, Column: 188
# Row: 28, Column: 230
# Row: 28, Column: 234
# Row: 28, Column: 253
# Row: 28, Column: 254
# Row: 29, Column: 2
# Row: 29, Column: 8
# Row: 29, Column: 31
# Row: 29, Column: 39
# Row: 29, Column: 43
# Row: 29, Column: 44
# Row: 29, Column: 80
# Row: 29, Column: 94
# Row: 29, Column: 97
# Row: 29, Column: 102
# Row: 29, Column: 117
# Row: 29, Column: 118
# Row: 29, Column: 121
# Row: 29, Column: 122
# Row: 29, Column: 126
# Row: 29, Column: 133
# Row: 29, Column: 141
# Row: 29, Column: 142
# Row: 29, Column: 143
# Row: 29, Column: 148
# Row: 29, Column: 153
# Row: 29, Column: 155
# Row: 29, Column: 159
# Row: 29, Column: 161
# Row: 29, Column: 169
# Row: 29, Column: 178
# Row: 29, Column: 211
# Row: 29, Column: 212
# Row: 29, Column: 213
# Row: 29, Column: 218
# Row: 29, Column: 239
# Row: 29, Column: 248
# Row: 30, Column: 15
# Row: 30, Column: 50
# Row: 30, Column: 60
# Row: 30, Column: 84
# Row: 30, Column: 88
# Row: 30, Column: 89
# Row: 30, Column: 98
# Row: 30, Column: 117
# Row: 30, Column: 118
# Row: 30, Column: 123
# Row: 30, Column: 128
# Row: 30, Column: 138
# Row: 30, Column: 140
# Row: 30, Column: 142
# Row: 30, Column: 143
# Row: 30, Column: 151
# Row: 30, Column: 174
# Row: 30, Column: 202
# Row: 30, Column: 207
# Row: 30, Column: 213
# Row: 30, Column: 219
# Row: 30, Column: 232
# Row: 30, Column: 241
# Row: 30, Column: 242
# Row: 31, Column: 2
# Row: 31, Column: 7
# Row: 31, Column: 44
# Row: 31, Column: 45
# Row: 31, Column: 68
# Row: 31, Column: 81
# Row: 31, Column: 93
# Row: 31, Column: 97
# Row: 31, Column: 98
# Row: 31, Column: 106
# Row: 31, Column: 138
# Row: 31, Column: 146
# Row: 31, Column: 149
# Row: 31, Column: 155
# Row: 31, Column: 168
# Row: 31, Column: 175
# Row: 31, Column: 199
# Row: 31, Column: 214
# Row: 31, Column: 222
# Row: 31, Column: 225
# Row: 31, Column: 229
# Row: 31, Column: 237
# Row: 31, Column: 238
# Row: 31, Column: 239
# Row: 31, Column: 243
# Row: 31, Column: 255
# Row: 32, Column: 1
# Row: 32, Column: 24
# Row: 32, Column: 83
# Row: 32, Column: 102
# Row: 32, Column: 104
# Row: 32, Column: 120
# Row: 32, Column: 125
# Row: 32, Column: 126
# Row: 32, Column: 132
# Row: 32, Column: 139
# Row: 32, Column: 140
# Row: 32, Column: 144
# Row: 32, Column: 157
# Row: 32, Column: 162
# Row: 32, Column: 181
# Row: 32, Column: 196
# Row: 32, Column: 200
# Row: 32, Column: 203
# Row: 32, Column: 209
# Row: 32, Column: 211
# Row: 32, Column: 223
# Row: 32, Column: 224
# Row: 32, Column: 225
# Row: 32, Column: 232
# Row: 32, Column: 238
# Row: 32, Column: 240
# Row: 32, Column: 247
# Row: 33, Column: 3
# Row: 33, Column: 9
# Row: 33, Column: 11
# Row: 33, Column: 18
# Row: 33, Column: 20
# Row: 33, Column: 69
# Row: 33, Column: 129
# Row: 33, Column: 132
# Row: 33, Column: 146
# Row: 33, Column: 148
# Row: 33, Column: 150
# Row: 33, Column: 153
# Row: 33, Column: 158
# Row: 33, Column: 159
# Row: 33, Column: 163
# Row: 33, Column: 169
# Row: 33, Column: 180
# Row: 33, Column: 187
# Row: 33, Column: 193
# Row: 33, Column: 194
# Row: 33, Column: 195
# Row: 33, Column: 216
# Row: 33, Column: 228
# Row: 33, Column: 240
# Row: 33, Column: 254
# Row: 34, Column: 9
# Row: 34, Column: 14
# Row: 34, Column: 25
# Row: 34, Column: 56
# Row: 34, Column: 67
# Row: 34, Column: 76
# Row: 34, Column: 77
# Row: 34, Column: 100
# Row: 34, Column: 127
# Row: 34, Column: 128
# Row: 34, Column: 149
# Row: 34, Column: 166
# Row: 34, Column: 173
# Row: 34, Column: 176
# Row: 34, Column: 183
# Row: 34, Column: 203
# Row: 35, Column: 6
# Row: 35, Column: 9
# Row: 35, Column: 11
# Row: 35, Column: 22
# Row: 35, Column: 46
# Row: 35, Column: 52
# Row: 35, Column: 63
# Row: 35, Column: 75
# Row: 35, Column: 77
# Row: 35, Column: 89
# Row: 35, Column: 95
# Row: 35, Column: 96
# Row: 35, Column: 105
# Row: 35, Column: 107
# Row: 35, Column: 125
# Row: 35, Column: 127
# Row: 35, Column: 136
# Row: 35, Column: 142
# Row: 35, Column: 164
# Row: 35, Column: 193
# Row: 35, Column: 199
# Row: 35, Column: 212
# Row: 35, Column: 216
# Row: 35, Column: 218
# Row: 35, Column: 228
# Row: 35, Column: 234
# Row: 35, Column: 239
# Row: 35, Column: 247
# Row: 35, Column: 255
# Row: 36, Column: 0
# Row: 36, Column: 3
# Row: 36, Column: 6
# Row: 36, Column: 8
# Row: 36, Column: 9
# Row: 36, Column: 18
# Row: 36, Column: 27
# Row: 36, Column: 29
# Row: 36, Column: 34
# Row: 36, Column: 37
# Row: 36, Column: 63
# Row: 36, Column: 89
# Row: 36, Column: 101
# Row: 36, Column: 102
# Row: 36, Column: 109
# Row: 36, Column: 111
# Row: 36, Column: 113
# Row: 36, Column: 120
# Row: 36, Column: 125
# Row: 36, Column: 136
# Row: 36, Column: 138
# Row: 36, Column: 141
# Row: 36, Column: 143
# Row: 36, Column: 156
# Row: 36, Column: 172
# Row: 36, Column: 185
# Row: 36, Column: 191
# Row: 36, Column: 210
# Row: 36, Column: 213
# Row: 36, Column: 225
# Row: 36, Column: 233
# Row: 36, Column: 242
# Row: 36, Column: 254
# Row: 37, Column: 4
# Row: 37, Column: 59
# Row: 37, Column: 63
# Row: 37, Column: 65
# Row: 37, Column: 66
# Row: 37, Column: 95
# Row: 37, Column: 96
# Row: 37, Column: 114
# Row: 37, Column: 120
# Row: 37, Column: 139
# Row: 37, Column: 140
# Row: 37, Column: 150
# Row: 37, Column: 156
# Row: 37, Column: 158
# Row: 37, Column: 167
# Row: 37, Column: 180
# Row: 37, Column: 181
# Row: 37, Column: 183
# Row: 37, Column: 194
# Row: 37, Column: 197
# Row: 37, Column: 207
# Row: 37, Column: 221
# Row: 37, Column: 222
# Row: 37, Column: 226
# Row: 37, Column: 232
# Row: 37, Column: 243
# Row: 38, Column: 4
# Row: 38, Column: 7
# Row: 38, Column: 11
# Row: 38, Column: 15
# Row: 38, Column: 20
# Row: 38, Column: 22
# Row: 38, Column: 26
# Row: 38, Column: 28
# Row: 38, Column: 39
# Row: 38, Column: 60
# Row: 38, Column: 80
# Row: 38, Column: 92
# Row: 38, Column: 102
# Row: 38, Column: 107
# Row: 38, Column: 121
# Row: 38, Column: 129
# Row: 38, Column: 130
# Row: 38, Column: 138
# Row: 38, Column: 141
# Row: 38, Column: 146
# Row: 38, Column: 164
# Row: 38, Column: 167
# Row: 38, Column: 174
# Row: 38, Column: 178
# Row: 38, Column: 189
# Row: 38, Column: 215
# Row: 38, Column: 242
# Row: 39, Column: 1
# Row: 39, Column: 11
# Row: 39, Column: 21
# Row: 39, Column: 40
# Row: 39, Column: 76
# Row: 39, Column: 95
# Row: 39, Column: 100
# Row: 39, Column: 112
# Row: 39, Column: 128
# Row: 39, Column: 143
# Row: 39, Column: 182
# Row: 39, Column: 192
# Row: 39, Column: 194
# Row: 39, Column: 200
# Row: 39, Column: 207
# Row: 39, Column: 208
# Row: 39, Column: 228
# Row: 39, Column: 229
# Row: 39, Column: 237
# Row: 39, Column: 238
# Row: 40, Column: 0
# Row: 40, Column: 8
# Row: 40, Column: 9
# Row: 40, Column: 12
# Row: 40, Column: 22
# Row: 40, Column: 41
# Row: 40, Column: 63
# Row: 40, Column: 82
# Row: 40, Column: 86
# Row: 40, Column: 89
# Row: 40, Column: 101
# Row: 40, Column: 121
# Row: 40, Column: 208
# Row: 40, Column: 212
# Row: 40, Column: 223
# Row: 40, Column: 237
# Row: 41, Column: 2
# Row: 41, Column: 15
# Row: 41, Column: 28
# Row: 41, Column: 69
# Row: 41, Column: 90
# Row: 41, Column: 94
# Row: 41, Column: 96
# Row: 41, Column: 112
# Row: 41, Column: 120
# Row: 41, Column: 122
# Row: 41, Column: 180
# Row: 41, Column: 187
# Row: 41, Column: 193
# Row: 41, Column: 199
# Row: 41, Column: 200
# Row: 41, Column: 213
# Row: 41, Column: 245
# Row: 42, Column: 31
# Row: 42, Column: 48
# Row: 42, Column: 72
# Row: 42, Column: 82
# Row: 42, Column: 98
# Row: 42, Column: 118
# Row: 42, Column: 130
# Row: 42, Column: 140
# Row: 42, Column: 156
# Row: 42, Column: 157
# Row: 42, Column: 173
# Row: 42, Column: 178
# Row: 42, Column: 183
# Row: 42, Column: 184
# Row: 42, Column: 186
# Row: 42, Column: 190
# Row: 42, Column: 197
# Row: 42, Column: 203
# Row: 42, Column: 208
# Row: 42, Column: 228
# Row: 42, Column: 229
# Row: 42, Column: 232
# Row: 42, Column: 255
# Row: 43, Column: 3
# Row: 43, Column: 24
# Row: 43, Column: 25
# Row: 43, Column: 36
# Row: 43, Column: 40
# Row: 43, Column: 45
# Row: 43, Column: 51
# Row: 43, Column: 54
# Row: 43, Column: 60
# Row: 43, Column: 69
# Row: 43, Column: 79
# Row: 43, Column: 92
# Row: 43, Column: 93
# Row: 43, Column: 95
# Row: 43, Column: 110
# Row: 43, Column: 113
# Row: 43, Column: 116
# Row: 43, Column: 118
# Row: 43, Column: 119
# Row: 43, Column: 126
# Row: 43, Column: 131
# Row: 43, Column: 132
# Row: 43, Column: 135
# Row: 43, Column: 160
# Row: 43, Column: 167
# Row: 43, Column: 170
# Row: 43, Column: 189
# Row: 43, Column: 200
# Row: 43, Column: 201
# Row: 43, Column: 204
# Row: 43, Column: 212
# Row: 43, Column: 215
# Row: 43, Column: 223
# Row: 43, Column: 232
# Row: 43, Column: 247
# Row: 44, Column: 9
# Row: 44, Column: 26
# Row: 44, Column: 31
# Row: 44, Column: 44
# Row: 44, Column: 47
# Row: 44, Column: 65
# Row: 44, Column: 66
# Row: 44, Column: 77
# Row: 44, Column: 88
# Row: 44, Column: 90
# Row: 44, Column: 96
# Row: 44, Column: 100
# Row: 44, Column: 126
# Row: 44, Column: 142
# Row: 44, Column: 149
# Row: 44, Column: 160
# Row: 44, Column: 201
# Row: 44, Column: 203
# Row: 44, Column: 206
# Row: 44, Column: 216
# Row: 44, Column: 218
# Row: 44, Column: 219
# Row: 44, Column: 221
# Row: 44, Column: 240
# Row: 44, Column: 254
# Row: 45, Column: 8
# Row: 45, Column: 11
# Row: 45, Column: 17
# Row: 45, Column: 22
# Row: 45, Column: 28
# Row: 45, Column: 46
# Row: 45, Column: 52
# Row: 45, Column: 61
# Row: 45, Column: 96
# Row: 45, Column: 99
# Row: 45, Column: 101
# Row: 45, Column: 111
# Row: 45, Column: 143
# Row: 45, Column: 147
# Row: 45, Column: 151
# Row: 45, Column: 153
# Row: 45, Column: 154
# Row: 45, Column: 155
# Row: 45, Column: 157
# Row: 45, Column: 168
# Row: 45, Column: 179
# Row: 45, Column: 193
# Row: 45, Column: 195
# Row: 45, Column: 197
# Row: 45, Column: 200
# Row: 45, Column: 201
# Row: 45, Column: 202
# Row: 45, Column: 208
# Row: 45, Column: 210
# Row: 45, Column: 213
# Row: 45, Column: 214
# Row: 45, Column: 215
# Row: 45, Column: 216
# Row: 45, Column: 223
# Row: 45, Column: 229
# Row: 45, Column: 234
# Row: 45, Column: 240
# Row: 45, Column: 242
# Row: 46, Column: 3
# Row: 46, Column: 5
# Row: 46, Column: 6
# Row: 46, Column: 29
# Row: 46, Column: 30
# Row: 46, Column: 33
# Row: 46, Column: 42
# Row: 46, Column: 52
# Row: 46, Column: 53
# Row: 46, Column: 57
# Row: 46, Column: 63
# Row: 46, Column: 97
# Row: 46, Column: 102
# Row: 46, Column: 121
# Row: 46, Column: 132
# Row: 46, Column: 148
# Row: 46, Column: 164
# Row: 46, Column: 167
# Row: 46, Column: 177
# Row: 46, Column: 183
# Row: 46, Column: 189
# Row: 46, Column: 192
# Row: 46, Column: 193
# Row: 46, Column: 196
# Row: 46, Column: 200
# Row: 46, Column: 212
# Row: 46, Column: 221
# Row: 46, Column: 226
# Row: 46, Column: 234
# Row: 46, Column: 245
# Row: 47, Column: 7
# Row: 47, Column: 30
# Row: 47, Column: 46
# Row: 47, Column: 54
# Row: 47, Column: 58
# Row: 47, Column: 65
# Row: 47, Column: 77
# Row: 47, Column: 80
# Row: 47, Column: 81
# Row: 47, Column: 93
# Row: 47, Column: 94
# Row: 47, Column: 122
# Row: 47, Column: 126
# Row: 47, Column: 139
# Row: 47, Column: 142
# Row: 47, Column: 156
# Row: 47, Column: 157
# Row: 47, Column: 165
# Row: 47, Column: 175
# Row: 47, Column: 180
# Row: 47, Column: 186
# Row: 47, Column: 191
# Row: 47, Column: 192
# Row: 47, Column: 201
# Row: 47, Column: 202
# Row: 47, Column: 203
# Row: 47, Column: 222
# Row: 47, Column: 227
# Row: 47, Column: 231
# Row: 47, Column: 235
# Row: 47, Column: 236
# Row: 47, Column: 241
# Row: 48, Column: 6
# Row: 48, Column: 12
# Row: 48, Column: 14
# Row: 48, Column: 24
# Row: 48, Column: 25
# Row: 48, Column: 29
# Row: 48, Column: 33
# Row: 48, Column: 42
# Row: 48, Column: 43
# Row: 48, Column: 45
# Row: 48, Column: 65
# Row: 48, Column: 66
# Row: 48, Column: 67
# Row: 48, Column: 69
# Row: 48, Column: 76
# Row: 48, Column: 82
# Row: 48, Column: 95
# Row: 48, Column: 96
# Row: 48, Column: 120
# Row: 48, Column: 124
# Row: 48, Column: 139
# Row: 48, Column: 141
# Row: 48, Column: 147
# Row: 48, Column: 187
# Row: 48, Column: 197
# Row: 48, Column: 201
# Row: 48, Column: 203
# Row: 48, Column: 216
# Row: 48, Column: 220
# Row: 48, Column: 223
# Row: 48, Column: 225
# Row: 48, Column: 229
# Row: 48, Column: 236
# Row: 48, Column: 248
# Row: 49, Column: 21
# Row: 49, Column: 22
# Row: 49, Column: 24
# Row: 49, Column: 57
# Row: 49, Column: 59
# Row: 49, Column: 77
# Row: 49, Column: 81
# Row: 49, Column: 94
# Row: 49, Column: 106
# Row: 49, Column: 107
# Row: 49, Column: 113
# Row: 49, Column: 115
# Row: 49, Column: 117
# Row: 49, Column: 124
# Row: 49, Column: 158
# Row: 49, Column: 184
# Row: 49, Column: 187
# Row: 49, Column: 191
# Row: 49, Column: 199
# Row: 49, Column: 201
# Row: 49, Column: 206
# Row: 49, Column: 209
# Row: 49, Column: 217
# Row: 49, Column: 238
# Row: 49, Column: 245
# Row: 49, Column: 251
# Row: 50, Column: 11
# Row: 50, Column: 12
# Row: 50, Column: 27
# Row: 50, Column: 71
# Row: 50, Column: 82
# Row: 50, Column: 100
# Row: 50, Column: 105
# Row: 50, Column: 109
# Row: 50, Column: 111
# Row: 50, Column: 115
# Row: 50, Column: 119
# Row: 50, Column: 122
# Row: 50, Column: 125
# Row: 50, Column: 133
# Row: 50, Column: 147
# Row: 50, Column: 155
# Row: 50, Column: 156
# Row: 50, Column: 160
# Row: 50, Column: 162
# Row: 50, Column: 168
# Row: 50, Column: 174
# Row: 50, Column: 182
# Row: 50, Column: 192
# Row: 50, Column: 199
# Row: 50, Column: 201
# Row: 50, Column: 208
# Row: 50, Column: 221
# Row: 50, Column: 233
# Row: 50, Column: 252
# Row: 51, Column: 2
# Row: 51, Column: 9
# Row: 51, Column: 15
# Row: 51, Column: 26
# Row: 51, Column: 27
# Row: 51, Column: 39
# Row: 51, Column: 47
# Row: 51, Column: 49
# Row: 51, Column: 67
# Row: 51, Column: 68
# Row: 51, Column: 69
# Row: 51, Column: 91
# Row: 51, Column: 92
# Row: 51, Column: 98
# Row: 51, Column: 100
# Row: 51, Column: 107
# Row: 51, Column: 108
# Row: 51, Column: 112
# Row: 51, Column: 120
# Row: 51, Column: 123
# Row: 51, Column: 125
# Row: 51, Column: 134
# Row: 51, Column: 136
# Row: 51, Column: 138
# Row: 51, Column: 140
# Row: 51, Column: 161
# Row: 51, Column: 163
# Row: 51, Column: 166
# Row: 51, Column: 195
# Row: 51, Column: 243
# Row: 51, Column: 247
# Row: 51, Column: 253
# Row: 52, Column: 5
# Row: 52, Column: 20
# Row: 52, Column: 22
# Row: 52, Column: 46
# Row: 52, Column: 50
# Row: 52, Column: 58
# Row: 52, Column: 62
# Row: 52, Column: 65
# Row: 52, Column: 66
# Row: 52, Column: 75
# Row: 52, Column: 84
# Row: 52, Column: 88
# Row: 52, Column: 91
# Row: 52, Column: 94
# Row: 52, Column: 109
# Row: 52, Column: 112
# Row: 52, Column: 118
# Row: 52, Column: 121
# Row: 52, Column: 125
# Row: 52, Column: 128
# Row: 52, Column: 135
# Row: 52, Column: 142
# Row: 52, Column: 143
# Row: 52, Column: 154
# Row: 52, Column: 166
# Row: 52, Column: 167
# Row: 52, Column: 190
# Row: 52, Column: 195
# Row: 52, Column: 204
# Row: 52, Column: 208
# Row: 52, Column: 229
# Row: 52, Column: 234
# Row: 52, Column: 237
# Row: 52, Column: 248
# Row: 52, Column: 251
# Row: 52, Column: 254
# Row: 53, Column: 4
# Row: 53, Column: 11
# Row: 53, Column: 23
# Row: 53, Column: 42
# Row: 53, Column: 57
# Row: 53, Column: 65
# Row: 53, Column: 76
# Row: 53, Column: 82
# Row: 53, Column: 93
# Row: 53, Column: 94
# Row: 53, Column: 101
# Row: 53, Column: 108
# Row: 53, Column: 121
# Row: 53, Column: 122
# Row: 53, Column: 123
# Row: 53, Column: 125
# Row: 53, Column: 127
# Row: 53, Column: 128
# Row: 53, Column: 135
# Row: 53, Column: 136
# Row: 53, Column: 148
# Row: 53, Column: 157
# Row: 53, Column: 160
# Row: 53, Column: 169
# Row: 53, Column: 173
# Row: 53, Column: 185
# Row: 53, Column: 187
# Row: 53, Column: 192
# Row: 53, Column: 209
# Row: 53, Column: 212
# Row: 53, Column: 213
# Row: 53, Column: 216
# Row: 53, Column: 218
# Row: 53, Column: 235
# Row: 53, Column: 241
# Row: 53, Column: 242
# Row: 53, Column: 246
# Row: 53, Column: 252
# Row: 53, Column: 253
# Row: 54, Column: 0
# Row: 54, Column: 19
# Row: 54, Column: 36
# Row: 54, Column: 38
# Row: 54, Column: 62
# Row: 54, Column: 78
# Row: 54, Column: 87
# Row: 54, Column: 90
# Row: 54, Column: 101
# Row: 54, Column: 114
# Row: 54, Column: 121
# Row: 54, Column: 122
# Row: 54, Column: 126
# Row: 54, Column: 132
# Row: 54, Column: 153
# Row: 54, Column: 184
# Row: 54, Column: 193
# Row: 54, Column: 195
# Row: 54, Column: 203
# Row: 54, Column: 214
# Row: 54, Column: 217
# Row: 54, Column: 239
# Row: 54, Column: 245
# Row: 54, Column: 246
# Row: 54, Column: 247
# Row: 54, Column: 252
# Row: 55, Column: 11
# Row: 55, Column: 18
# Row: 55, Column: 32
# Row: 55, Column: 33
# Row: 55, Column: 34
# Row: 55, Column: 53
# Row: 55, Column: 63
# Row: 55, Column: 77
# Row: 55, Column: 94
# Row: 55, Column: 95
# Row: 55, Column: 97
# Row: 55, Column: 98
# Row: 55, Column: 99
# Row: 55, Column: 100
# Row: 55, Column: 105
# Row: 55, Column: 106
# Row: 55, Column: 107
# Row: 55, Column: 108
# Row: 55, Column: 112
# Row: 55, Column: 114
# Row: 55, Column: 122
# Row: 55, Column: 132
# Row: 55, Column: 133
# Row: 55, Column: 137
# Row: 55, Column: 141
# Row: 55, Column: 147
# Row: 55, Column: 152
# Row: 55, Column: 159
# Row: 55, Column: 217
# Row: 55, Column: 228
# Row: 55, Column: 231
# Row: 55, Column: 234
# Row: 55, Column: 250
# Row: 55, Column: 252
# Row: 55, Column: 254
# Row: 56, Column: 9
# Row: 56, Column: 17
# Row: 56, Column: 19
# Row: 56, Column: 41
# Row: 56, Column: 62
# Row: 56, Column: 65
# Row: 56, Column: 66
# Row: 56, Column: 67
# Row: 56, Column: 86
# Row: 56, Column: 91
# Row: 56, Column: 92
# Row: 56, Column: 95
# Row: 56, Column: 100
# Row: 56, Column: 101
# Row: 56, Column: 102
# Row: 56, Column: 115
# Row: 56, Column: 118
# Row: 56, Column: 119
# Row: 56, Column: 122
# Row: 56, Column: 123
# Row: 56, Column: 124
# Row: 56, Column: 127
# Row: 56, Column: 132
# Row: 56, Column: 137
# Row: 56, Column: 138
# Row: 56, Column: 139
# Row: 56, Column: 142
# Row: 56, Column: 146
# Row: 56, Column: 149
# Row: 56, Column: 153
# Row: 56, Column: 172
# Row: 56, Column: 173
# Row: 56, Column: 178
# Row: 56, Column: 196
# Row: 56, Column: 205
# Row: 56, Column: 229
# Row: 56, Column: 233
# Row: 56, Column: 235
# Row: 56, Column: 243
# Row: 56, Column: 251
# Row: 57, Column: 2
# Row: 57, Column: 9
# Row: 57, Column: 18
# Row: 57, Column: 39
# Row: 57, Column: 40
# Row: 57, Column: 47
# Row: 57, Column: 49
# Row: 57, Column: 52
# Row: 57, Column: 64
# Row: 57, Column: 67
# Row: 57, Column: 97
# Row: 57, Column: 102
# Row: 57, Column: 106
# Row: 57, Column: 113
# Row: 57, Column: 120
# Row: 57, Column: 121
# Row: 57, Column: 122
# Row: 57, Column: 125
# Row: 57, Column: 127
# Row: 57, Column: 129
# Row: 57, Column: 131
# Row: 57, Column: 139
# Row: 57, Column: 144
# Row: 57, Column: 154
# Row: 57, Column: 163
# Row: 57, Column: 173
# Row: 57, Column: 175
# Row: 57, Column: 176
# Row: 57, Column: 177
# Row: 57, Column: 180
# Row: 57, Column: 185
# Row: 57, Column: 187
# Row: 57, Column: 196
# Row: 57, Column: 239
# Row: 57, Column: 240
# Row: 57, Column: 252
# Row: 58, Column: 9
# Row: 58, Column: 18
# Row: 58, Column: 19
# Row: 58, Column: 43
# Row: 58, Column: 44
# Row: 58, Column: 45
# Row: 58, Column: 53
# Row: 58, Column: 65
# Row: 58, Column: 83
# Row: 58, Column: 91
# Row: 58, Column: 92
# Row: 58, Column: 100
# Row: 58, Column: 102
# Row: 58, Column: 111
# Row: 58, Column: 115
# Row: 58, Column: 121
# Row: 58, Column: 123
# Row: 58, Column: 124
# Row: 58, Column: 127
# Row: 58, Column: 128
# Row: 58, Column: 134
# Row: 58, Column: 144
# Row: 58, Column: 164
# Row: 58, Column: 170
# Row: 58, Column: 171
# Row: 58, Column: 172
# Row: 58, Column: 174
# Row: 58, Column: 180
# Row: 58, Column: 181
# Row: 58, Column: 194
# Row: 58, Column: 195
# Row: 58, Column: 197
# Row: 58, Column: 198
# Row: 58, Column: 199
# Row: 58, Column: 206
# Row: 58, Column: 207
# Row: 58, Column: 240
# Row: 59, Column: 16
# Row: 59, Column: 26
# Row: 59, Column: 28
# Row: 59, Column: 36
# Row: 59, Column: 37
# Row: 59, Column: 48
# Row: 59, Column: 51
# Row: 59, Column: 55
# Row: 59, Column: 78
# Row: 59, Column: 82
# Row: 59, Column: 91
# Row: 59, Column: 97
# Row: 59, Column: 111
# Row: 59, Column: 112
# Row: 59, Column: 115
# Row: 59, Column: 118
# Row: 59, Column: 123
# Row: 59, Column: 126
# Row: 59, Column: 135
# Row: 59, Column: 144
# Row: 59, Column: 149
# Row: 59, Column: 151
# Row: 59, Column: 165
# Row: 59, Column: 167
# Row: 59, Column: 172
# Row: 59, Column: 177
# Row: 59, Column: 179
# Row: 59, Column: 210
# Row: 59, Column: 218
# Row: 59, Column: 223
# Row: 59, Column: 233
# Row: 59, Column: 234
# Row: 59, Column: 250
# Row: 60, Column: 6
# Row: 60, Column: 39
# Row: 60, Column: 42
# Row: 60, Column: 50
# Row: 60, Column: 51
# Row: 60, Column: 59
# Row: 60, Column: 61
# Row: 60, Column: 62
# Row: 60, Column: 64
# Row: 60, Column: 70
# Row: 60, Column: 91
# Row: 60, Column: 94
# Row: 60, Column: 96
# Row: 60, Column: 99
# Row: 60, Column: 108
# Row: 60, Column: 111
# Row: 60, Column: 119
# Row: 60, Column: 121
# Row: 60, Column: 122
# Row: 60, Column: 130
# Row: 60, Column: 144
# Row: 60, Column: 154
# Row: 60, Column: 172
# Row: 60, Column: 177
# Row: 60, Column: 178
# Row: 60, Column: 180
# Row: 60, Column: 181
# Row: 60, Column: 186
# Row: 60, Column: 193
# Row: 60, Column: 201
# Row: 60, Column: 208
# Row: 60, Column: 224
# Row: 60, Column: 233
# Row: 60, Column: 234
# Row: 60, Column: 251
# Row: 60, Column: 253
# Row: 61, Column: 32
# Row: 61, Column: 45
# Row: 61, Column: 58
# Row: 61, Column: 64
# Row: 61, Column: 83
# Row: 61, Column: 110
# Row: 61, Column: 113
# Row: 61, Column: 115
# Row: 61, Column: 126
# Row: 61, Column: 129
# Row: 61, Column: 130
# Row: 61, Column: 143
# Row: 61, Column: 148
# Row: 61, Column: 152
# Row: 61, Column: 156
# Row: 61, Column: 169
# Row: 61, Column: 180
# Row: 61, Column: 182
# Row: 61, Column: 198
# Row: 61, Column: 215
# Row: 61, Column: 231
# Row: 61, Column: 241
# Row: 62, Column: 5
# Row: 62, Column: 18
# Row: 62, Column: 24
# Row: 62, Column: 30
# Row: 62, Column: 31
# Row: 62, Column: 54
# Row: 62, Column: 58
# Row: 62, Column: 65
# Row: 62, Column: 76
# Row: 62, Column: 100
# Row: 62, Column: 106
# Row: 62, Column: 108
# Row: 62, Column: 112
# Row: 62, Column: 114
# Row: 62, Column: 116
# Row: 62, Column: 121
# Row: 62, Column: 122
# Row: 62, Column: 123
# Row: 62, Column: 128
# Row: 62, Column: 129
# Row: 62, Column: 144
# Row: 62, Column: 150
# Row: 62, Column: 182
# Row: 62, Column: 184
# Row: 62, Column: 196
# Row: 62, Column: 201
# Row: 62, Column: 206
# Row: 63, Column: 2
# Row: 63, Column: 8
# Row: 63, Column: 25
# Row: 63, Column: 26
# Row: 63, Column: 32
# Row: 63, Column: 35
# Row: 63, Column: 40
# Row: 63, Column: 41
# Row: 63, Column: 48
# Row: 63, Column: 61
# Row: 63, Column: 70
# Row: 63, Column: 80
# Row: 63, Column: 100
# Row: 63, Column: 104
# Row: 63, Column: 113
# Row: 63, Column: 115
# Row: 63, Column: 123
# Row: 63, Column: 127
# Row: 63, Column: 151
# Row: 63, Column: 168
# Row: 63, Column: 184
# Row: 63, Column: 185
# Row: 63, Column: 202
# Row: 63, Column: 204
# Row: 63, Column: 205
# Row: 63, Column: 206
# Row: 63, Column: 221
# Row: 63, Column: 229
# Row: 63, Column: 241
# Row: 64, Column: 9
# Row: 64, Column: 22
# Row: 64, Column: 27
# Row: 64, Column: 41
# Row: 64, Column: 44
# Row: 64, Column: 63
# Row: 64, Column: 70
# Row: 64, Column: 83
# Row: 64, Column: 84
# Row: 64, Column: 103
# Row: 64, Column: 106
# Row: 64, Column: 110
# Row: 64, Column: 117
# Row: 64, Column: 119
# Row: 64, Column: 127
# Row: 64, Column: 133
# Row: 64, Column: 136
# Row: 64, Column: 138
# Row: 64, Column: 152
# Row: 64, Column: 154
# Row: 64, Column: 155
# Row: 64, Column: 160
# Row: 64, Column: 162
# Row: 64, Column: 164
# Row: 64, Column: 171
# Row: 64, Column: 173
# Row: 64, Column: 174
# Row: 64, Column: 185
# Row: 64, Column: 187
# Row: 64, Column: 189
# Row: 64, Column: 206
# Row: 64, Column: 223
# Row: 64, Column: 224
# Row: 64, Column: 231
# Row: 64, Column: 242
# Row: 65, Column: 8
# Row: 65, Column: 26
# Row: 65, Column: 29
# Row: 65, Column: 31
# Row: 65, Column: 53
# Row: 65, Column: 54
# Row: 65, Column: 60
# Row: 65, Column: 69
# Row: 65, Column: 78
# Row: 65, Column: 84
# Row: 65, Column: 85
# Row: 65, Column: 92
# Row: 65, Column: 95
# Row: 65, Column: 96
# Row: 65, Column: 98
# Row: 65, Column: 99
# Row: 65, Column: 102
# Row: 65, Column: 115
# Row: 65, Column: 116
# Row: 65, Column: 126
# Row: 65, Column: 136
# Row: 65, Column: 137
# Row: 65, Column: 142
# Row: 65, Column: 143
# Row: 65, Column: 149
# Row: 65, Column: 154
# Row: 65, Column: 156
# Row: 65, Column: 158
# Row: 65, Column: 171
# Row: 65, Column: 172
# Row: 65, Column: 184
# Row: 65, Column: 185
# Row: 65, Column: 188
# Row: 65, Column: 206
# Row: 65, Column: 217
# Row: 65, Column: 221
# Row: 65, Column: 232
# Row: 65, Column: 239
# Row: 65, Column: 242
# Row: 65, Column: 255
# Row: 66, Column: 1
# Row: 66, Column: 2
# Row: 66, Column: 3
# Row: 66, Column: 4
# Row: 66, Column: 19
# Row: 66, Column: 25
# Row: 66, Column: 37
# Row: 66, Column: 52
# Row: 66, Column: 55
# Row: 66, Column: 70
# Row: 66, Column: 79
# Row: 66, Column: 82
# Row: 66, Column: 94
# Row: 66, Column: 100
# Row: 66, Column: 102
# Row: 66, Column: 105
# Row: 66, Column: 107
# Row: 66, Column: 110
# Row: 66, Column: 117
# Row: 66, Column: 123
# Row: 66, Column: 124
# Row: 66, Column: 129
# Row: 66, Column: 137
# Row: 66, Column: 140
# Row: 66, Column: 142
# Row: 66, Column: 145
# Row: 66, Column: 157
# Row: 66, Column: 158
# Row: 66, Column: 159
# Row: 66, Column: 162
# Row: 66, Column: 176
# Row: 66, Column: 186
# Row: 66, Column: 189
# Row: 66, Column: 191
# Row: 66, Column: 208
# Row: 66, Column: 217
# Row: 66, Column: 218
# Row: 66, Column: 222
# Row: 66, Column: 224
# Row: 66, Column: 226
# Row: 66, Column: 234
# Row: 66, Column: 242
# Row: 66, Column: 247
# Row: 66, Column: 254
# Row: 67, Column: 4
# Row: 67, Column: 5
# Row: 67, Column: 13
# Row: 67, Column: 28
# Row: 67, Column: 32
# Row: 67, Column: 34
# Row: 67, Column: 37
# Row: 67, Column: 55
# Row: 67, Column: 61
# Row: 67, Column: 62
# Row: 67, Column: 63
# Row: 67, Column: 64
# Row: 67, Column: 69
# Row: 67, Column: 71
# Row: 67, Column: 75
# Row: 67, Column: 77
# Row: 67, Column: 80
# Row: 67, Column: 81
# Row: 67, Column: 92
# Row: 67, Column: 96
# Row: 67, Column: 98
# Row: 67, Column: 105
# Row: 67, Column: 107
# Row: 67, Column: 109
# Row: 67, Column: 110
# Row: 67, Column: 112
# Row: 67, Column: 114
# Row: 67, Column: 115
# Row: 67, Column: 116
# Row: 67, Column: 118
# Row: 67, Column: 119
# Row: 67, Column: 123
# Row: 67, Column: 125
# Row: 67, Column: 133
# Row: 67, Column: 135
# Row: 67, Column: 138
# Row: 67, Column: 139
# Row: 67, Column: 140
# Row: 67, Column: 146
# Row: 67, Column: 153
# Row: 67, Column: 158
# Row: 67, Column: 179
# Row: 67, Column: 181
# Row: 67, Column: 190
# Row: 67, Column: 192
# Row: 67, Column: 193
# Row: 67, Column: 194
# Row: 67, Column: 196
# Row: 67, Column: 198
# Row: 67, Column: 204
# Row: 67, Column: 205
# Row: 67, Column: 206
# Row: 67, Column: 209
# Row: 67, Column: 219
# Row: 67, Column: 225
# Row: 67, Column: 227
# Row: 67, Column: 228
# Row: 67, Column: 244
# Row: 67, Column: 251
# Row: 68, Column: 1
# Row: 68, Column: 4
# Row: 68, Column: 21
# Row: 68, Column: 25
# Row: 68, Column: 26
# Row: 68, Column: 46
# Row: 68, Column: 47
# Row: 68, Column: 58
# Row: 68, Column: 67
# Row: 68, Column: 82
# Row: 68, Column: 85
# Row: 68, Column: 86
# Row: 68, Column: 109
# Row: 68, Column: 121
# Row: 68, Column: 126
# Row: 68, Column: 131
# Row: 68, Column: 137
# Row: 68, Column: 138
# Row: 68, Column: 140
# Row: 68, Column: 147
# Row: 68, Column: 148
# Row: 68, Column: 157
# Row: 68, Column: 162
# Row: 68, Column: 170
# Row: 68, Column: 172
# Row: 68, Column: 190
# Row: 68, Column: 200
# Row: 68, Column: 203
# Row: 68, Column: 211
# Row: 68, Column: 212
# Row: 68, Column: 215
# Row: 68, Column: 217
# Row: 68, Column: 218
# Row: 68, Column: 221
# Row: 68, Column: 228
# Row: 68, Column: 238
# Row: 68, Column: 250
# Row: 68, Column: 253
# Row: 68, Column: 254
# Row: 69, Column: 26
# Row: 69, Column: 36
# Row: 69, Column: 38
# Row: 69, Column: 50
# Row: 69, Column: 51
# Row: 69, Column: 55
# Row: 69, Column: 62
# Row: 69, Column: 66
# Row: 69, Column: 87
# Row: 69, Column: 92
# Row: 69, Column: 98
# Row: 69, Column: 100
# Row: 69, Column: 102
# Row: 69, Column: 104
# Row: 69, Column: 119
# Row: 69, Column: 122
# Row: 69, Column: 123
# Row: 69, Column: 130
# Row: 69, Column: 131
# Row: 69, Column: 145
# Row: 69, Column: 146
# Row: 69, Column: 154
# Row: 69, Column: 156
# Row: 69, Column: 162
# Row: 69, Column: 163
# Row: 69, Column: 164
# Row: 69, Column: 165
# Row: 69, Column: 170
# Row: 69, Column: 184
# Row: 69, Column: 187
# Row: 69, Column: 188
# Row: 69, Column: 190
# Row: 69, Column: 193
# Row: 69, Column: 196
# Row: 69, Column: 210
# Row: 69, Column: 212
# Row: 69, Column: 215
# Row: 69, Column: 222
# Row: 69, Column: 225
# Row: 69, Column: 236
# Row: 69, Column: 238
# Row: 69, Column: 239
# Row: 69, Column: 241
# Row: 70, Column: 19
# Row: 70, Column: 21
# Row: 70, Column: 24
# Row: 70, Column: 28
# Row: 70, Column: 29
# Row: 70, Column: 36
# Row: 70, Column: 40
# Row: 70, Column: 41
# Row: 70, Column: 64
# Row: 70, Column: 70
# Row: 70, Column: 88
# Row: 70, Column: 92
# Row: 70, Column: 104
# Row: 70, Column: 106
# Row: 70, Column: 114
# Row: 70, Column: 119
# Row: 70, Column: 122
# Row: 70, Column: 124
# Row: 70, Column: 126
# Row: 70, Column: 127
# Row: 70, Column: 130
# Row: 70, Column: 132
# Row: 70, Column: 133
# Row: 70, Column: 136
# Row: 70, Column: 138
# Row: 70, Column: 141
# Row: 70, Column: 154
# Row: 70, Column: 155
# Row: 70, Column: 159
# Row: 70, Column: 160
# Row: 70, Column: 163
# Row: 70, Column: 167
# Row: 70, Column: 171
# Row: 70, Column: 176
# Row: 70, Column: 192
# Row: 70, Column: 203
# Row: 70, Column: 206
# Row: 70, Column: 207
# Row: 70, Column: 208
# Row: 70, Column: 210
# Row: 70, Column: 213
# Row: 70, Column: 215
# Row: 70, Column: 219
# Row: 70, Column: 221
# Row: 70, Column: 225
# Row: 70, Column: 230
# Row: 70, Column: 233
# Row: 70, Column: 245
# Row: 71, Column: 21
# Row: 71, Column: 22
# Row: 71, Column: 31
# Row: 71, Column: 36
# Row: 71, Column: 41
# Row: 71, Column: 43
# Row: 71, Column: 49
# Row: 71, Column: 56
# Row: 71, Column: 58
# Row: 71, Column: 62
# Row: 71, Column: 67
# Row: 71, Column: 70
# Row: 71, Column: 92
# Row: 71, Column: 93
# Row: 71, Column: 94
# Row: 71, Column: 96
# Row: 71, Column: 97
# Row: 71, Column: 102
# Row: 71, Column: 106
# Row: 71, Column: 107
# Row: 71, Column: 108
# Row: 71, Column: 116
# Row: 71, Column: 117
# Row: 71, Column: 118
# Row: 71, Column: 120
# Row: 71, Column: 139
# Row: 71, Column: 140
# Row: 71, Column: 145
# Row: 71, Column: 152
# Row: 71, Column: 158
# Row: 71, Column: 160
# Row: 71, Column: 161
# Row: 71, Column: 171
# Row: 71, Column: 174
# Row: 71, Column: 186
# Row: 71, Column: 191
# Row: 71, Column: 198
# Row: 71, Column: 201
# Row: 71, Column: 211
# Row: 71, Column: 212
# Row: 71, Column: 216
# Row: 71, Column: 224
# Row: 71, Column: 227
# Row: 71, Column: 246
# Row: 72, Column: 10
# Row: 72, Column: 26
# Row: 72, Column: 35
# Row: 72, Column: 37
# Row: 72, Column: 51
# Row: 72, Column: 56
# Row: 72, Column: 63
# Row: 72, Column: 68
# Row: 72, Column: 70
# Row: 72, Column: 81
# Row: 72, Column: 88
# Row: 72, Column: 95
# Row: 72, Column: 103
# Row: 72, Column: 108
# Row: 72, Column: 112
# Row: 72, Column: 114
# Row: 72, Column: 116
# Row: 72, Column: 118
# Row: 72, Column: 119
# Row: 72, Column: 123
# Row: 72, Column: 124
# Row: 72, Column: 126
# Row: 72, Column: 134
# Row: 72, Column: 145
# Row: 72, Column: 148
# Row: 72, Column: 152
# Row: 72, Column: 153
# Row: 72, Column: 159
# Row: 72, Column: 162
# Row: 72, Column: 163
# Row: 72, Column: 170
# Row: 72, Column: 174
# Row: 72, Column: 175
# Row: 72, Column: 179
# Row: 72, Column: 185
# Row: 72, Column: 192
# Row: 72, Column: 193
# Row: 72, Column: 194
# Row: 72, Column: 197
# Row: 72, Column: 202
# Row: 72, Column: 204
# Row: 72, Column: 210
# Row: 72, Column: 211
# Row: 72, Column: 223
# Row: 72, Column: 226
# Row: 72, Column: 228
# Row: 73, Column: 6
# Row: 73, Column: 10
# Row: 73, Column: 22
# Row: 73, Column: 30
# Row: 73, Column: 32
# Row: 73, Column: 35
# Row: 73, Column: 39
# Row: 73, Column: 61
# Row: 73, Column: 63
# Row: 73, Column: 78
# Row: 73, Column: 80
# Row: 73, Column: 108
# Row: 73, Column: 109
# Row: 73, Column: 111
# Row: 73, Column: 113
# Row: 73, Column: 129
# Row: 73, Column: 130
# Row: 73, Column: 132
# Row: 73, Column: 140
# Row: 73, Column: 146
# Row: 73, Column: 147
# Row: 73, Column: 149
# Row: 73, Column: 150
# Row: 73, Column: 151
# Row: 73, Column: 201
# Row: 73, Column: 209
# Row: 73, Column: 213
# Row: 73, Column: 215
# Row: 73, Column: 221
# Row: 73, Column: 222
# Row: 73, Column: 226
# Row: 73, Column: 239
# Row: 73, Column: 241
# Row: 73, Column: 245
# Row: 73, Column: 247
# Row: 73, Column: 251
# Row: 73, Column: 252
# Row: 73, Column: 255
# Row: 74, Column: 13
# Row: 74, Column: 30
# Row: 74, Column: 32
# Row: 74, Column: 35
# Row: 74, Column: 39
# Row: 74, Column: 48
# Row: 74, Column: 51
# Row: 74, Column: 66
# Row: 74, Column: 71
# Row: 74, Column: 80
# Row: 74, Column: 96
# Row: 74, Column: 98
# Row: 74, Column: 113
# Row: 74, Column: 124
# Row: 74, Column: 135
# Row: 74, Column: 149
# Row: 74, Column: 155
# Row: 74, Column: 175
# Row: 74, Column: 181
# Row: 74, Column: 182
# Row: 74, Column: 189
# Row: 74, Column: 196
# Row: 74, Column: 216
# Row: 74, Column: 219
# Row: 74, Column: 220
# Row: 74, Column: 222
# Row: 74, Column: 232
# Row: 74, Column: 234
# Row: 74, Column: 240
# Row: 74, Column: 245
# Row: 75, Column: 30
# Row: 75, Column: 45
# Row: 75, Column: 63
# Row: 75, Column: 64
# Row: 75, Column: 65
# Row: 75, Column: 89
# Row: 75, Column: 94
# Row: 75, Column: 95
# Row: 75, Column: 100
# Row: 75, Column: 124
# Row: 75, Column: 132
# Row: 75, Column: 136
# Row: 75, Column: 138
# Row: 75, Column: 142
# Row: 75, Column: 153
# Row: 75, Column: 154
# Row: 75, Column: 155
# Row: 75, Column: 156
# Row: 75, Column: 158
# Row: 75, Column: 164
# Row: 75, Column: 165
# Row: 75, Column: 170
# Row: 75, Column: 172
# Row: 75, Column: 175
# Row: 75, Column: 198
# Row: 75, Column: 206
# Row: 75, Column: 214
# Row: 75, Column: 216
# Row: 75, Column: 217
# Row: 75, Column: 218
# Row: 75, Column: 219
# Row: 75, Column: 227
# Row: 75, Column: 230
# Row: 75, Column: 231
# Row: 75, Column: 233
# Row: 75, Column: 235
# Row: 75, Column: 236
# Row: 75, Column: 239
# Row: 75, Column: 247
# Row: 75, Column: 250
# Row: 76, Column: 19
# Row: 76, Column: 20
# Row: 76, Column: 31
# Row: 76, Column: 36
# Row: 76, Column: 41
# Row: 76, Column: 47
# Row: 76, Column: 48
# Row: 76, Column: 55
# Row: 76, Column: 56
# Row: 76, Column: 61
# Row: 76, Column: 69
# Row: 76, Column: 70
# Row: 76, Column: 76
# Row: 76, Column: 81
# Row: 76, Column: 84
# Row: 76, Column: 95
# Row: 76, Column: 102
# Row: 76, Column: 106
# Row: 76, Column: 116
# Row: 76, Column: 140
# Row: 76, Column: 141
# Row: 76, Column: 144
# Row: 76, Column: 150
# Row: 76, Column: 156
# Row: 76, Column: 165
# Row: 76, Column: 170
# Row: 76, Column: 178
# Row: 76, Column: 181
# Row: 76, Column: 203
# Row: 76, Column: 205
# Row: 76, Column: 217
# Row: 76, Column: 222
# Row: 76, Column: 228
# Row: 76, Column: 232
# Row: 76, Column: 235
# Row: 76, Column: 237
# Row: 76, Column: 238
# Row: 76, Column: 244
# Row: 76, Column: 247
# Row: 76, Column: 252
# Row: 77, Column: 30
# Row: 77, Column: 32
# Row: 77, Column: 35
# Row: 77, Column: 41
# Row: 77, Column: 42
# Row: 77, Column: 48
# Row: 77, Column: 59
# Row: 77, Column: 64
# Row: 77, Column: 65
# Row: 77, Column: 68
# Row: 77, Column: 78
# Row: 77, Column: 82
# Row: 77, Column: 93
# Row: 77, Column: 95
# Row: 77, Column: 97
# Row: 77, Column: 114
# Row: 77, Column: 115
# Row: 77, Column: 118
# Row: 77, Column: 122
# Row: 77, Column: 128
# Row: 77, Column: 130
# Row: 77, Column: 131
# Row: 77, Column: 132
# Row: 77, Column: 136
# Row: 77, Column: 137
# Row: 77, Column: 139
# Row: 77, Column: 141
# Row: 77, Column: 144
# Row: 77, Column: 156
# Row: 77, Column: 162
# Row: 77, Column: 163
# Row: 77, Column: 170
# Row: 77, Column: 175
# Row: 77, Column: 177
# Row: 77, Column: 187
# Row: 77, Column: 194
# Row: 77, Column: 197
# Row: 77, Column: 198
# Row: 77, Column: 203
# Row: 77, Column: 215
# Row: 77, Column: 218
# Row: 77, Column: 221
# Row: 77, Column: 225
# Row: 77, Column: 226
# Row: 77, Column: 228
# Row: 77, Column: 230
# Row: 77, Column: 231
# Row: 77, Column: 237
# Row: 78, Column: 4
# Row: 78, Column: 5
# Row: 78, Column: 7
# Row: 78, Column: 30
# Row: 78, Column: 36
# Row: 78, Column: 40
# Row: 78, Column: 46
# Row: 78, Column: 47
# Row: 78, Column: 61
# Row: 78, Column: 66
# Row: 78, Column: 67
# Row: 78, Column: 79
# Row: 78, Column: 93
# Row: 78, Column: 95
# Row: 78, Column: 104
# Row: 78, Column: 120
# Row: 78, Column: 128
# Row: 78, Column: 130
# Row: 78, Column: 133
# Row: 78, Column: 134
# Row: 78, Column: 135
# Row: 78, Column: 141
# Row: 78, Column: 147
# Row: 78, Column: 148
# Row: 78, Column: 159
# Row: 78, Column: 162
# Row: 78, Column: 164
# Row: 78, Column: 167
# Row: 78, Column: 173
# Row: 78, Column: 175
# Row: 78, Column: 178
# Row: 78, Column: 180
# Row: 78, Column: 196
# Row: 78, Column: 206
# Row: 78, Column: 218
# Row: 78, Column: 223
# Row: 78, Column: 226
# Row: 78, Column: 227
# Row: 78, Column: 231
# Row: 78, Column: 232
# Row: 78, Column: 234
# Row: 78, Column: 235
# Row: 78, Column: 240
# Row: 78, Column: 243
# Row: 78, Column: 255
# Row: 79, Column: 3
# Row: 79, Column: 10
# Row: 79, Column: 11
# Row: 79, Column: 29
# Row: 79, Column: 30
# Row: 79, Column: 51
# Row: 79, Column: 60
# ...
# Row: 234, Column: 108
# Row: 234, Column: 112
# Row: 234, Column: 116
# Row: 234, Column: 130
# Row: 234, Column: 134
# Row: 234, Column: 139
# Row: 234, Column: 153
# Row: 234, Column: 157
# Row: 234, Column: 180
# Row: 234, Column: 181
# Row: 234, Column: 191
# Row: 234, Column: 212
# Row: 234, Column: 238
# Row: 235, Column: 3
# Row: 235, Column: 14
# Row: 235, Column: 21
# Row: 235, Column: 24
# Row: 235, Column: 27
# Row: 235, Column: 28
# Row: 235, Column: 36
# Row: 235, Column: 42
# Row: 235, Column: 44
# Row: 235, Column: 55
# Row: 235, Column: 60
# Row: 235, Column: 63
# Row: 235, Column: 65
# Row: 235, Column: 67
# Row: 235, Column: 72
# Row: 235, Column: 74
# Row: 235, Column: 90
# Row: 235, Column: 104
# Row: 235, Column: 115
# Row: 235, Column: 118
# Row: 235, Column: 119
# Row: 235, Column: 125
# Row: 235, Column: 134
# Row: 235, Column: 144
# Row: 235, Column: 154
# Row: 235, Column: 157
# Row: 235, Column: 158
# Row: 235, Column: 171
# Row: 235, Column: 179
# Row: 235, Column: 198
# Row: 235, Column: 203
# Row: 235, Column: 211
# Row: 235, Column: 212
# Row: 235, Column: 232
# Row: 235, Column: 233
# Row: 235, Column: 238
# Row: 235, Column: 247
# Row: 235, Column: 253
# Row: 236, Column: 23
# Row: 236, Column: 24
# Row: 236, Column: 39
# Row: 236, Column: 43
# Row: 236, Column: 57
# Row: 236, Column: 69
# Row: 236, Column: 73
# Row: 236, Column: 96
# Row: 236, Column: 101
# Row: 236, Column: 110
# Row: 236, Column: 134
# Row: 236, Column: 144
# Row: 236, Column: 145
# Row: 236, Column: 152
# Row: 236, Column: 178
# Row: 236, Column: 179
# Row: 236, Column: 185
# Row: 236, Column: 186
# Row: 236, Column: 187
# Row: 236, Column: 189
# Row: 236, Column: 203
# Row: 236, Column: 207
# Row: 236, Column: 211
# Row: 236, Column: 237
# Row: 237, Column: 7
# Row: 237, Column: 10
# Row: 237, Column: 11
# Row: 237, Column: 25
# Row: 237, Column: 42
# Row: 237, Column: 47
# Row: 237, Column: 55
# Row: 237, Column: 77
# Row: 237, Column: 79
# Row: 237, Column: 95
# Row: 237, Column: 96
# Row: 237, Column: 107
# Row: 237, Column: 110
# Row: 237, Column: 111
# Row: 237, Column: 114
# Row: 237, Column: 123
# Row: 237, Column: 130
# Row: 237, Column: 134
# Row: 237, Column: 140
# Row: 237, Column: 168
# Row: 237, Column: 170
# Row: 237, Column: 178
# Row: 237, Column: 179
# Row: 237, Column: 185
# Row: 237, Column: 187
# Row: 237, Column: 191
# Row: 237, Column: 200
# Row: 237, Column: 208
# Row: 237, Column: 209
# Row: 237, Column: 211
# Row: 238, Column: 2
# Row: 238, Column: 36
# Row: 238, Column: 93
# Row: 238, Column: 94
# Row: 238, Column: 101
# Row: 238, Column: 108
# Row: 238, Column: 109
# Row: 238, Column: 122
# Row: 238, Column: 127
# Row: 238, Column: 133
# Row: 238, Column: 143
# Row: 238, Column: 148
# Row: 238, Column: 150
# Row: 238, Column: 157
# Row: 238, Column: 165
# Row: 238, Column: 170
# Row: 238, Column: 171
# Row: 238, Column: 174
# Row: 238, Column: 206
# Row: 238, Column: 211
# Row: 238, Column: 232
# Row: 238, Column: 234
# Row: 238, Column: 237
# Row: 239, Column: 16
# Row: 239, Column: 42
# Row: 239, Column: 99
# Row: 239, Column: 107
# Row: 239, Column: 133
# Row: 239, Column: 136
# Row: 239, Column: 151
# Row: 239, Column: 155
# Row: 239, Column: 156
# Row: 239, Column: 172
# Row: 239, Column: 173
# Row: 239, Column: 196
# Row: 239, Column: 206
# Row: 239, Column: 242
# Row: 239, Column: 247
# Row: 239, Column: 248
# Row: 239, Column: 250
# Row: 240, Column: 25
# Row: 240, Column: 34
# Row: 240, Column: 44
# Row: 240, Column: 68
# Row: 240, Column: 74
# Row: 240, Column: 92
# Row: 240, Column: 94
# Row: 240, Column: 101
# Row: 240, Column: 107
# Row: 240, Column: 115
# Row: 240, Column: 137
# Row: 240, Column: 138
# Row: 240, Column: 149
# Row: 240, Column: 152
# Row: 240, Column: 164
# Row: 240, Column: 166
# Row: 240, Column: 183
# Row: 240, Column: 187
# Row: 240, Column: 192
# Row: 240, Column: 193
# Row: 240, Column: 205
# Row: 240, Column: 236
# Row: 240, Column: 238
# Row: 240, Column: 253
# Row: 241, Column: 5
# Row: 241, Column: 10
# Row: 241, Column: 13
# Row: 241, Column: 20
# Row: 241, Column: 28
# Row: 241, Column: 34
# Row: 241, Column: 40
# Row: 241, Column: 43
# Row: 241, Column: 44
# Row: 241, Column: 52
# Row: 241, Column: 61
# Row: 241, Column: 70
# Row: 241, Column: 74
# Row: 241, Column: 112
# Row: 241, Column: 119
# Row: 241, Column: 130
# Row: 241, Column: 140
# Row: 241, Column: 141
# Row: 241, Column: 143
# Row: 241, Column: 146
# Row: 241, Column: 148
# Row: 241, Column: 166
# Row: 241, Column: 179
# Row: 241, Column: 191
# Row: 241, Column: 226
# Row: 241, Column: 232
# Row: 242, Column: 28
# Row: 242, Column: 45
# Row: 242, Column: 55
# Row: 242, Column: 70
# Row: 242, Column: 110
# Row: 242, Column: 113
# Row: 242, Column: 114
# Row: 242, Column: 119
# Row: 242, Column: 121
# Row: 242, Column: 133
# Row: 242, Column: 139
# Row: 242, Column: 147
# Row: 242, Column: 150
# Row: 242, Column: 153
# Row: 242, Column: 172
# Row: 242, Column: 181
# Row: 242, Column: 195
# Row: 242, Column: 232
# Row: 242, Column: 235
# Row: 242, Column: 239
# Row: 242, Column: 247
# Row: 242, Column: 248
# Row: 242, Column: 250
# Row: 243, Column: 1
# Row: 243, Column: 4
# Row: 243, Column: 9
# Row: 243, Column: 10
# Row: 243, Column: 11
# Row: 243, Column: 21
# Row: 243, Column: 31
# Row: 243, Column: 33
# Row: 243, Column: 44
# Row: 243, Column: 62
# Row: 243, Column: 66
# Row: 243, Column: 91
# Row: 243, Column: 95
# Row: 243, Column: 109
# Row: 243, Column: 114
# Row: 243, Column: 116
# Row: 243, Column: 124
# Row: 243, Column: 157
# Row: 243, Column: 164
# Row: 243, Column: 165
# Row: 243, Column: 190
# Row: 243, Column: 196
# Row: 243, Column: 212
# Row: 243, Column: 220
# Row: 243, Column: 229
# Row: 243, Column: 237
# Row: 243, Column: 239
# Row: 243, Column: 242
# Row: 243, Column: 246
# Row: 244, Column: 1
# Row: 244, Column: 5
# Row: 244, Column: 19
# Row: 244, Column: 22
# Row: 244, Column: 25
# Row: 244, Column: 56
# Row: 244, Column: 61
# Row: 244, Column: 62
# Row: 244, Column: 64
# Row: 244, Column: 72
# Row: 244, Column: 90
# Row: 244, Column: 101
# Row: 244, Column: 113
# Row: 244, Column: 117
# Row: 244, Column: 121
# Row: 244, Column: 131
# Row: 244, Column: 132
# Row: 244, Column: 141
# Row: 244, Column: 148
# Row: 244, Column: 154
# Row: 244, Column: 171
# Row: 244, Column: 193
# Row: 244, Column: 197
# Row: 244, Column: 202
# Row: 244, Column: 213
# Row: 244, Column: 231
# Row: 244, Column: 236
# Row: 244, Column: 254
# Row: 245, Column: 2
# Row: 245, Column: 9
# Row: 245, Column: 49
# Row: 245, Column: 55
# Row: 245, Column: 74
# Row: 245, Column: 77
# Row: 245, Column: 90
# Row: 245, Column: 91
# Row: 245, Column: 122
# Row: 245, Column: 141
# Row: 245, Column: 149
# Row: 245, Column: 164
# Row: 245, Column: 165
# Row: 245, Column: 171
# Row: 245, Column: 173
# Row: 245, Column: 185
# Row: 245, Column: 201
# Row: 245, Column: 229
# Row: 245, Column: 233
# Row: 245, Column: 237
# Row: 245, Column: 247
# Row: 245, Column: 248
# Row: 246, Column: 2
# Row: 246, Column: 10
# Row: 246, Column: 23
# Row: 246, Column: 50
# Row: 246, Column: 52
# Row: 246, Column: 80
# Row: 246, Column: 99
# Row: 246, Column: 113
# Row: 246, Column: 114
# Row: 246, Column: 115
# Row: 246, Column: 124
# Row: 246, Column: 145
# Row: 246, Column: 148
# Row: 246, Column: 149
# Row: 246, Column: 154
# Row: 246, Column: 156
# Row: 246, Column: 176
# Row: 246, Column: 186
# Row: 246, Column: 205
# Row: 246, Column: 206
# Row: 247, Column: 3
# Row: 247, Column: 12
# Row: 247, Column: 22
# Row: 247, Column: 24
# Row: 247, Column: 25
# Row: 247, Column: 26
# Row: 247, Column: 27
# Row: 247, Column: 28
# Row: 247, Column: 53
# Row: 247, Column: 58
# Row: 247, Column: 64
# Row: 247, Column: 65
# Row: 247, Column: 68
# Row: 247, Column: 110
# Row: 247, Column: 111
# Row: 247, Column: 113
# Row: 247, Column: 125
# Row: 247, Column: 127
# Row: 247, Column: 128
# Row: 247, Column: 143
# Row: 247, Column: 166
# Row: 247, Column: 185
# Row: 247, Column: 195
# Row: 247, Column: 209
# Row: 247, Column: 229
# Row: 247, Column: 236
# Row: 247, Column: 239
# Row: 247, Column: 244
# Row: 247, Column: 245
# Row: 248, Column: 22
# Row: 248, Column: 55
# Row: 248, Column: 64
# Row: 248, Column: 69
# Row: 248, Column: 78
# Row: 248, Column: 103
# Row: 248, Column: 127
# Row: 248, Column: 131
# Row: 248, Column: 134
# Row: 248, Column: 139
# Row: 248, Column: 155
# Row: 248, Column: 165
# Row: 248, Column: 177
# Row: 248, Column: 178
# Row: 248, Column: 179
# Row: 248, Column: 181
# Row: 248, Column: 185
# Row: 248, Column: 194
# Row: 248, Column: 218
# Row: 248, Column: 224
# Row: 248, Column: 225
# Row: 248, Column: 231
# Row: 248, Column: 241
# Row: 248, Column: 243
# Row: 248, Column: 249
# Row: 248, Column: 255
# Row: 249, Column: 42
# Row: 249, Column: 53
# Row: 249, Column: 66
# Row: 249, Column: 82
# Row: 249, Column: 102
# Row: 249, Column: 126
# Row: 249, Column: 129
# Row: 249, Column: 132
# Row: 249, Column: 133
# Row: 249, Column: 135
# Row: 249, Column: 136
# Row: 249, Column: 149
# Row: 249, Column: 157
# Row: 249, Column: 163
# Row: 249, Column: 171
# Row: 249, Column: 176
# Row: 249, Column: 186
# Row: 249, Column: 188
# Row: 249, Column: 196
# Row: 249, Column: 218
# Row: 249, Column: 227
# Row: 250, Column: 0
# Row: 250, Column: 2
# Row: 250, Column: 8
# Row: 250, Column: 20
# Row: 250, Column: 26
# Row: 250, Column: 27
# Row: 250, Column: 42
# Row: 250, Column: 63
# Row: 250, Column: 78
# Row: 250, Column: 93
# Row: 250, Column: 111
# Row: 250, Column: 126
# Row: 250, Column: 128
# Row: 250, Column: 129
# Row: 250, Column: 131
# Row: 250, Column: 134
# Row: 250, Column: 135
# Row: 250, Column: 139
# Row: 250, Column: 140
# Row: 250, Column: 144
# Row: 250, Column: 152
# Row: 250, Column: 170
# Row: 250, Column: 173
# Row: 250, Column: 195
# Row: 250, Column: 196
# Row: 250, Column: 207
# Row: 250, Column: 208
# Row: 250, Column: 212
# Row: 250, Column: 225
# Row: 250, Column: 230
# Row: 250, Column: 239
# Row: 250, Column: 243
# Row: 250, Column: 251
# Row: 251, Column: 9
# Row: 251, Column: 11
# Row: 251, Column: 12
# Row: 251, Column: 13
# Row: 251, Column: 14
# Row: 251, Column: 23
# Row: 251, Column: 25
# Row: 251, Column: 90
# Row: 251, Column: 93
# Row: 251, Column: 110
# Row: 251, Column: 115
# Row: 251, Column: 134
# Row: 251, Column: 144
# Row: 251, Column: 157
# Row: 251, Column: 190
# Row: 251, Column: 198
# Row: 251, Column: 209
# Row: 251, Column: 235
# Row: 251, Column: 244
# Row: 251, Column: 247
# Row: 251, Column: 249
# Row: 251, Column: 254
# Row: 252, Column: 12
# Row: 252, Column: 34
# Row: 252, Column: 37
# Row: 252, Column: 42
# Row: 252, Column: 69
# Row: 252, Column: 83
# Row: 252, Column: 115
# Row: 252, Column: 116
# Row: 252, Column: 130
# Row: 252, Column: 134
# Row: 252, Column: 135
# Row: 252, Column: 138
# Row: 252, Column: 139
# Row: 252, Column: 145
# Row: 252, Column: 161
# Row: 252, Column: 185
# Row: 252, Column: 197
# Row: 252, Column: 209
# Row: 252, Column: 223
# Row: 252, Column: 232
# Row: 252, Column: 233
# Row: 252, Column: 250
# Row: 253, Column: 6
# Row: 253, Column: 10
# Row: 253, Column: 26
# Row: 253, Column: 29
# Row: 253, Column: 31
# Row: 253, Column: 32
# Row: 253, Column: 43
# Row: 253, Column: 44
# Row: 253, Column: 45
# Row: 253, Column: 47
# Row: 253, Column: 52
# Row: 253, Column: 69
# Row: 253, Column: 77
# Row: 253, Column: 79
# Row: 253, Column: 102
# Row: 253, Column: 109
# Row: 253, Column: 112
# Row: 253, Column: 113
# Row: 253, Column: 124
# Row: 253, Column: 128
# Row: 253, Column: 140
# Row: 253, Column: 142
# Row: 253, Column: 152
# Row: 253, Column: 163
# Row: 253, Column: 167
# Row: 253, Column: 170
# Row: 253, Column: 183
# Row: 253, Column: 193
# Row: 253, Column: 237
# Row: 253, Column: 244
# Row: 253, Column: 245
# Row: 253, Column: 246
# Row: 254, Column: 5
# Row: 254, Column: 20
# Row: 254, Column: 22
# Row: 254, Column: 47
# Row: 254, Column: 56
# Row: 254, Column: 84
# Row: 254, Column: 86
# Row: 254, Column: 96
# Row: 254, Column: 98
# Row: 254, Column: 122
# Row: 254, Column: 129
# Row: 254, Column: 130
# Row: 254, Column: 145
# Row: 254, Column: 146
# Row: 254, Column: 155
# Row: 254, Column: 159
# Row: 254, Column: 182
# Row: 254, Column: 184
# Row: 254, Column: 187
# Row: 254, Column: 196
# Row: 254, Column: 213
# Row: 254, Column: 216
# Row: 254, Column: 239
# Row: 254, Column: 242
# Row: 254, Column: 252
# Row: 255, Column: 8
# Row: 255, Column: 10
# Row: 255, Column: 26
# Row: 255, Column: 32
# Row: 255, Column: 43
# Row: 255, Column: 48
# Row: 255, Column: 53
# Row: 255, Column: 84
# Row: 255, Column: 106
# Row: 255, Column: 114
# Row: 255, Column: 121
# Row: 255, Column: 150
# Row: 255, Column: 152
# Row: 255, Column: 154
# Row: 255, Column: 157
# Row: 255, Column: 159
# Row: 255, Column: 162
# Row: 255, Column: 164
# Row: 255, Column: 165
# Row: 255, Column: 194
# Row: 255, Column: 202
# Row: 255, Column: 212
# Row: 255, Column: 213
# Row: 255, Column: 216
# Row: 255, Column: 238
# Row: 255, Column: 240
# Row: 255, Column: 242
# [(0, 19), (0, 20), (0, 25), (0, 33), (0, 48), (0, 62), (0, 63), (0, 73), (0, 101), (0, 102), (0, 104), (0, 112), (0, 140), (0, 167), (0, 183), (0, 185), (0, 193), (0, 205), (0, 224), (0, 230), (0, 237), (0, 245), (0, 249), (1, 2), (1, 4), (1, 8), (1, 15), (1, 18), (1, 22), (1, 64), (1, 78), (1, 87), (1, 94), (1, 95), (1, 97), (1, 98), (1, 99), (1, 100), (1, 113), (1, 115), (1, 124), (1, 126), (1, 129), (1, 131), (1, 137), (1, 148), (1, 154), (1, 166), (1, 171), (1, 175), (1, 194), (1, 201), (1, 212), (1, 214), (1, 229), (1, 250), (1, 251), (1, 252), (2, 1), (2, 10), (2, 16), (2, 18), (2, 22), (2, 35), (2, 44), (2, 59), (2, 68), (2, 77), (2, 88), (2, 90), (2, 92), (2, 93), (2, 95), (2, 98), (2, 99), (2, 107), (2, 113), (2, 139), (2, 156), (2, 159), (2, 160), (2, 173), (2, 175), (2, 180), (2, 181), (2, 188), (2, 212), (2, 223), (2, 229), (2, 236), (2, 239), (2, 247), (3, 7), (3, 15), (3, 20), (3, 40), (3, 82), (3, 88), (3, 90), (3, 97), (3, 100), (3, 103), (3, 105), (3, 107), (3, 109), (3, 111), (3, 129), (3, 132), (3, 143), (3, 145), (3, 239), (3, 249), (4, 9), (4, 15), (4, 47), (4, 89), (4, 98), (4, 99), (4, 105), (4, 106), (4, 116), (4, 117), (4, 135), (4, 160), (4, 174), (4, 177), (4, 210), (4, 211), (4, 225), (4, 232), (4, 237), (4, 242), (4, 244), (4, 246), (4, 253), (4, 254), (5, 19), (5, 20), (5, 25), (5, 39), (5, 96), (5, 117), (5, 122), (5, 135), (5, 137), (5, 138), (5, 151), (5, 152), (5, 166), (5, 214), (5, 232), (5, 233), (5, 248), (5, 250), (5, 252), (6, 7), (6, 36), (6, 37), (6, 47), (6, 73), (6, 76), (6, 92), (6, 103), (6, 110), (6, 116), (6, 126), (6, 127), (6, 153), (6, 154), (6, 164), (6, 172), (6, 185), (6, 207), (6, 209), (6, 210), (6, 211), (6, 217), (6, 226), (6, 246), (6, 250), (6, 253), (7, 14), (7, 18), (7, 23), (7, 33), (7, 39), (7, 47), (7, 52), (7, 81), (7, 89), (7, 92), (7, 94), (7, 98), (7, 105), (7, 119), (7, 125), (7, 129), (7, 160), (7, 173), (7, 193), (7, 196), (7, 208), (7, 209), (7, 226), (7, 228), (8, 0), (8, 2), (8, 15), (8, 16), (8, 18), (8, 37), (8, 41), (8, 47), (8, 66), (8, 75), (8, 87), (8, 96), (8, 97), (8, 101), (8, 102), (8, 104), (8, 107), (8, 111), (8, 132), (8, 134), (8, 167), (8, 184), (8, 192), (8, 196), (8, 206), (8, 214), (8, 216), (9, 13), (9, 18), (9, 33), (9, 38), (9, 50), (9, 55), (9, 56), (9, 61), (9, 68), (9, 94), (9, 128), (9, 131), (9, 161), (9, 168), (9, 196), (9, 203), (9, 204), (9, 215), (9, 246), (9, 247), (10, 13), (10, 14), (10, 18), (10, 20), (10, 21), (10, 31), (10, 43), (10, 58), (10, 84), (10, 88), (10, 89), (10, 94), (10, 107), (10, 122), (10, 132), (10, 140), (10, 141), (10, 142), (10, 167), (10, 189), (10, 216), (10, 226), (10, 241), (10, 246), (11, 14), (11, 16), (11, 50), (11, 51), (11, 61), (11, 65), (11, 83), (11, 88), (11, 89), (11, 92), (11, 118), (11, 122), (11, 125), (11, 130), (11, 132), (11, 134), (11, 140), (11, 166), (11, 192), (11, 197), (11, 198), (11, 204), (11, 209), (11, 248), (12, 0), (12, 13), (12, 31), (12, 52), (12, 90), (12, 96), (12, 102), (12, 128), (12, 130), (12, 131), (12, 139), (12, 141), (12, 145), (12, 151), (12, 176), (12, 188), (12, 191), (12, 193), (12, 195), (12, 216), (12, 228), (12, 230), (12, 240), (12, 243), (12, 244), (12, 245), (12, 255), (13, 0), (13, 42), (13, 72), (13, 79), (13, 92), (13, 104), (13, 109), (13, 112), (13, 126), (13, 134), (13, 142), (13, 157), (13, 191), (13, 196), (13, 217), (13, 239), (13, 254), (14, 3), (14, 13), (14, 79), (14, 84), (14, 113), (14, 124), (14, 151), (14, 159), (14, 168), (14, 201), (14, 204), (14, 218), (14, 234), (14, 255), (15, 10), (15, 13), (15, 32), (15, 33), (15, 34), (15, 72), (15, 75), (15, 82), (15, 91), (15, 114), (15, 124), (15, 127), (15, 142), (15, 150), (15, 169), (15, 173), (15, 180), (15, 194), (15, 204), (15, 210), (15, 224), (15, 234), (15, 242), (15, 243), (15, 249), (16, 3), (16, 4), (16, 6), (16, 10), (16, 21), (16, 24), (16, 25), (16, 42), (16, 52), (16, 56), (16, 83), (16, 107), (16, 113), (16, 119), (16, 120), (16, 133), (16, 142), (16, 152), (16, 168), ( ...

# %%
# n        = 30
# rank     = 8
# m        = int(0.4 * n**(1.25) * rank * np.log(n))
# M        = np.dot(np.random.randn(n, rank), np.random.randn(n, rank).T)
# X, omega = mask_out_matrix(im, coords) # strictly speaking, not necessary

# print("Nuclear Norm of original matrix M: {:6.4f}".format(np.linalg.norm(M, "nuc")))
# print('Average entry-wise difference before recovery:', np.mean(np.abs(M - X)))

recovered = complete_matrix(noisy_im, updated_coords)
recovered

# print('Average entry-wise difference after recovery:', np.mean(np.abs(M - recovered)))
# print("Nuclear Norm of recoverd matrix: {:6.4f}".format(np.linalg.norm(recovered, "nuc")))

# %%
_, ax_image = plt.subplots()
ax_image.imshow(im, cmap='gray')
ax_image.set_title('Original Image')

fig_noisy, ax_noisy = plt.subplots()
ax_noisy.imshow(noisy_im, cmap='gray')
ax_noisy.set_title(f'Noisy Image, PSNR={round(PSNR(original_im=im, cleaned_im=noisy_im), 2)}')

fig_quad, ax_quad = plt.subplots()
ax_quad.imshow(quad_im, cmap='gray')
ax_quad.set_title(f'Quadratic Image, PSNR={round(PSNR(original_im=im, cleaned_im=quad_im), 2)}')

fig_tv, ax_tv = plt.subplots()
ax_tv.imshow(TV_im, cmap='gray')
ax_tv.set_title(f'TV Image, PSNR={round(PSNR(original_im=im, cleaned_im=TV_im), 2)}')

_, ax_rec_image = plt.subplots()
ax_rec_image.imshow(recovered, cmap='gray')
ax_rec_image.set_title(f'Exact Matrix Image, PSNR={round(PSNR(original_im=im, cleaned_im=recovered), 2)}')
